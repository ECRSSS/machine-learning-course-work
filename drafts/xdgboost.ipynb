# %%
import xgboost as xgb

from sklearn.metrics import roc_auc_score

from hpsklearn import HyperoptEstimator, svc, xgboost_classification, any_classifier, any_preprocessing

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, mean_absolute_error
from sklearn.model_selection import train_test_split 
from sklearn.neural_network import MLPClassifier

# %%
merged_df = pd.read_csv('processed_data/prepared_featured_balanced_sample_5.csv').drop('Unnamed: 0',axis=1)

# %%
x = merged_df.drop(['event_target'],axis=1)
y = merged_df['event_target']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
def fit_and_result(clf):
    clf.fit(X_train, y_train)

    clf_train_pred = clf.predict(X_train)
    clf_test_pred = clf.predict(X_test)

    print('Точность на тренировочной выборке')
    print(accuracy_score(y_train, clf_train_pred))
    print('Точность на тестовой выборке')
    print(accuracy_score(y_test, clf_test_pred))
    
    
    score = roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])
    print(f"\n\nROC AUC TEST: {score:.4f}")

# %%
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter("ignore")

# %%
from hyperopt import hp, STATUS_OK, Trials, fmin, tpe
from sklearn.model_selection import cross_val_score


def objective(space):

    warnings.filterwarnings(action='ignore', category=DeprecationWarning)
    classifier = xgb.XGBClassifier(n_estimators = space['n_estimators'],
                            max_depth = int(space['max_depth']),
                            learning_rate = space['learning_rate'],
                            gamma = space['gamma'],
                            min_child_weight = space['min_child_weight'],
                            subsample = space['subsample'],
                            colsample_bytree = space['colsample_bytree'],
                            booster = 'gbtree'
                            )
    
    classifier.fit(X_train, y_train)

    # Applying k-Fold Cross Validation
    from sklearn.model_selection import cross_val_score
    accuracies = cross_val_score(estimator = classifier, scoring='roc_auc', X = X_test, y = y_test, cv = 10)
    CrossValMean = accuracies.mean()
    
    print('---------')
    print("CrossValMean AUC SCORE:", CrossValMean)


    return{'loss':1-CrossValMean, 'status': STATUS_OK }

space = {
     'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
    'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
    
    'max_depth' : hp.choice('max_depth', range(5, 30, 1)),
    'learning_rate' : hp.quniform('learning_rate', 0.01, 0.5, 0.01),
    'n_estimators' : hp.choice('n_estimators', range(20, 800, 50)),
    'gamma' : hp.quniform('gamma', 0, 0.50, 0.01),
    'min_child_weight' : hp.quniform('min_child_weight', 1, 10, 1),
    'subsample' : hp.quniform('subsample', 0.1, 1, 0.01),
    'colsample_bytree' : hp.quniform('colsample_bytree', 0.1, 1.0, 0.01),
    'eta' : hp.quniform('eta', 0.1, 1 , 0.1),
  #  'tree_method' : hp.choice('tree_method', ('auto', 'exact', 'approx', 'hist'))
}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=200,
            trials=trials)

print("Best: ", best)


# Fitting XGBoost to the Training set
from xgboost import XGBClassifier
classifier = XGBClassifier(n_estimators = best['n_estimators'],
                            max_depth = best['max_depth'],
                            learning_rate = best['learning_rate'],
                            gamma = best['gamma'],
                            min_child_weight = best['min_child_weight'],
                            subsample = best['subsample'],
                            colsample_bytree = best['colsample_bytree'],
                            eta = best['eta'],
                            tree_method = best['tree_method']
                            )

classifier.fit(X_train, y_train)
# Out:
# ---------
# CrossValMean AUC SCORE:
# 0.65855237148217
# ---------
# CrossValMean AUC SCORE:
# 0.6250307376983804
# ---------
# CrossValMean AUC SCORE:
# 0.6485965424451797
# ---------
# CrossValMean AUC SCORE:
# 0.6238923203478832
# ---------
# CrossValMean AUC SCORE:
# 0.5775825434905031
# ---------
# CrossValMean AUC SCORE:
# 0.6634409029387978
# ---------
# CrossValMean AUC SCORE:
# 0.6120603979676533
# ---------
# CrossValMean AUC SCORE:
# 0.6115148899762644
# ---------
# CrossValMean AUC SCORE:
# 0.5749100212028283
# ---------
# CrossValMean AUC SCORE:
# 0.6321923289454505
# ---------
# CrossValMean AUC SCORE:
# 0.5891411813397613
# ---------
# CrossValMean AUC SCORE:
# 0.6116650307758513
# ---------
# CrossValMean AUC SCORE:
# 0.5867073461683681
# ---------
# CrossValMean AUC SCORE:
# 0.6222818341895716
# ---------
# CrossValMean AUC SCORE:
# 0.651478639936089
# ---------
# CrossValMean AUC SCORE:
# 0.6511570159185663
# ---------
# CrossValMean AUC SCORE:
# 0.6261541103177183
# ---------
# CrossValMean AUC SCORE:
# 0.6161482171073175
# ---------
# CrossValMean AUC SCORE:
# 0.6207630844929428
# ---------
# CrossValMean AUC SCORE:
# 0.6362700543715997
# ---------
# CrossValMean AUC SCORE:
# 0.6629520048693096
# ---------
# CrossValMean AUC SCORE:
# 0.6643041594137047
# ---------
# CrossValMean AUC SCORE:
# 0.6649034081299089
# ---------
# CrossValMean AUC SCORE:
# 0.6315916152653418
# ---------
# CrossValMean AUC SCORE:
# 0.6517832223952026
# ---------
# CrossValMean AUC SCORE:
# 0.6108521859532028
# ---------
# CrossValMean AUC SCORE:
# 0.6341947151870685
# ---------
# CrossValMean AUC SCORE:
# 0.6247502506664941
# ---------
# CrossValMean AUC SCORE:
# 0.6147715912149025
# ---------
# CrossValMean AUC SCORE:
# 0.6631850345346286
# ---------
# CrossValMean AUC SCORE:
# 0.629617022989991
# ---------
# CrossValMean AUC SCORE:
# 0.6643349124345426
# ---------
# CrossValMean AUC SCORE:
# 0.6422439198014299
# ---------
# CrossValMean AUC SCORE:
# 0.6483382886043435
# ---------
# CrossValMean AUC SCORE:
# 0.6213743910505461
# ---------
# CrossValMean AUC SCORE:
# 0.6639273710848903
# ---------
# CrossValMean AUC SCORE:
# 0.6636630426935745
# ---------
# CrossValMean AUC SCORE:
# 0.6272229532202359
# ---------
# CrossValMean AUC SCORE:
# 0.6366568592045178
# ---------
# CrossValMean AUC SCORE:
# 0.610152320521059
# ---------
# CrossValMean AUC SCORE:
# 0.625059685314719
# ---------
# CrossValMean AUC SCORE:
# 0.6568863927476183
# ---------
# CrossValMean AUC SCORE:
# 0.6376607017801331
# ---------
# CrossValMean AUC SCORE:
# 0.6388342103108556
# ---------
# CrossValMean AUC SCORE:
# 0.6095392373704281
# ---------
# CrossValMean AUC SCORE:
# 0.6325466969711098
# ---------
# CrossValMean AUC SCORE:
# 0.6153999687019999
# ---------
# CrossValMean AUC SCORE:
# 0.6010177914175225
# ---------
# CrossValMean AUC SCORE:
# 0.6312601208093964
# ---------
# CrossValMean AUC SCORE:
# 0.6485243493137796
# ---------
# CrossValMean AUC SCORE:
# 0.6257167073160395
# ---------
# CrossValMean AUC SCORE:
# 0.647470088001525
# ---------
# CrossValMean AUC SCORE:
# 0.6138898796559848
# ---------
# CrossValMean AUC SCORE:
# 0.64787086227509
# ---------
# CrossValMean AUC SCORE:
# 0.6545939033977122
# ---------
# CrossValMean AUC SCORE:
# 0.6256546875918639
# ---------
# CrossValMean AUC SCORE:
# 0.6306547670184391
# ---------
# CrossValMean AUC SCORE:
# 0.6237835157025633
# ---------
# CrossValMean AUC SCORE:
# 0.6303634937905163
# ---------
# CrossValMean AUC SCORE:
# 0.581143982615801
# ---------
# CrossValMean AUC SCORE:
# 0.6202257136064822
# ---------
# CrossValMean AUC SCORE:
# 0.6318403915639934
# ---------
# CrossValMean AUC SCORE:
# 0.6619918618138622
# ---------
# CrossValMean AUC SCORE:
# 0.6276078277149687
# ---------
# CrossValMean AUC SCORE:
# 0.6089994873804614
# ---------
# CrossValMean AUC SCORE:
# 0.6652657050706343
# ---------
# CrossValMean AUC SCORE:
# 0.6663281697320508
# ---------
# CrossValMean AUC SCORE:
# 0.655595450488935
# ---------
# CrossValMean AUC SCORE:
# 0.6624943577346329
# ---------
# CrossValMean AUC SCORE:
# 0.6308572404390012
# ---------
# CrossValMean AUC SCORE:
# 0.6259410187564632
# ---------
# CrossValMean AUC SCORE:
# 0.6619835295103137
# ---------
# CrossValMean AUC SCORE:
# 0.6488821605538623
# ---------
# CrossValMean AUC SCORE:
# 0.6537826023750095
# ---------
# CrossValMean AUC SCORE:
# 0.6340370102546707
# ---------
# CrossValMean AUC SCORE:
# 0.6181525153151759
# ---------
# CrossValMean AUC SCORE:
# 0.6290416643776504
# ---------
# CrossValMean AUC SCORE:
# 0.6470591714654501
# ---------
# CrossValMean AUC SCORE:
# 0.6640067438987668
# ---------
# CrossValMean AUC SCORE:
# 0.6503411598072174
# ---------
# CrossValMean AUC SCORE:
# 0.6442996751044918
# ---------
# CrossValMean AUC SCORE:
# 0.6558283991476833
# ---------
# CrossValMean AUC SCORE:
# 0.6043812129246444
# ---------
# CrossValMean AUC SCORE:
# 0.6079448014656128
# ---------
# CrossValMean AUC SCORE:
# 0.6636021254280255
# ---------
# CrossValMean AUC SCORE:
# 0.6532555856042593
# ---------
# CrossValMean AUC SCORE:
# 0.6252160534833371
# ---------
# CrossValMean AUC SCORE:
# 0.6302289992446264
# ---------
# CrossValMean AUC SCORE:
# 0.6570975489792813
# ---------
# CrossValMean AUC SCORE:
# 0.6634928010245483
# ---------
# CrossValMean AUC SCORE:
# 0.6071081119139119
# ---------
# CrossValMean AUC SCORE:
# 0.6162382078905562
# ---------
# CrossValMean AUC SCORE:
# 0.6506172981474274
# ---------
# CrossValMean AUC SCORE:
# 0.616221996130308
# ---------
# CrossValMean AUC SCORE:
# 0.6289945134703718
# ---------
# CrossValMean AUC SCORE:
# 0.6617665142345728
# ---------
# CrossValMean AUC SCORE:
# 0.6196734733394555
# ---------
# CrossValMean AUC SCORE:
# 0.6406426358398083
# ---------
# CrossValMean AUC SCORE:
# 0.6357851392555256
# ---------
# CrossValMean AUC SCORE:
# 0.625001469097643
# ---------
# CrossValMean AUC SCORE:
# 0.6367905925124888
# ---------
# CrossValMean AUC SCORE:
# 0.6559803042855761
# ---------
# CrossValMean AUC SCORE:
# 0.6129014873279611
# ---------
# CrossValMean AUC SCORE:
# 0.6290433537008981
# ---------
# CrossValMean AUC SCORE:
# 0.598717208697183
# ---------
# CrossValMean AUC SCORE:
# 0.6234836867550826
# ---------
# CrossValMean AUC SCORE:
# 0.6564947340396524
# ---------
# CrossValMean AUC SCORE:
# 0.633622490562716
# ---------
# CrossValMean AUC SCORE:
# 0.6604173840304406
# ---------
# CrossValMean AUC SCORE:
# 0.6207491723351117
# ---------
# CrossValMean AUC SCORE:
# 0.6317143017282221
# ---------
# CrossValMean AUC SCORE:
# 0.6645047844677824
# ---------
# CrossValMean AUC SCORE:
# 0.6178239056428668
# ---------
# CrossValMean AUC SCORE:
# 0.6467116667070307
# ---------
# CrossValMean AUC SCORE:
# 0.6501300557209776
# ---------
# CrossValMean AUC SCORE:
# 0.6318981723182249
# ---------
# CrossValMean AUC SCORE:
# 0.6205042284168727
# ---------
# CrossValMean AUC SCORE:
# 0.6456148257005115
# ---------
# CrossValMean AUC SCORE:
# 0.6409640206048712
# ---------
# CrossValMean AUC SCORE:
# 0.6170657241655148
# ---------
# CrossValMean AUC SCORE:
# 0.6596419018282967
# ---------
# CrossValMean AUC SCORE:
# 0.6326422261303308
# ---------
# CrossValMean AUC SCORE:
# 0.6262429490242913
# ---------
# CrossValMean AUC SCORE:
# 0.6497170730548082
# ---------
# CrossValMean AUC SCORE:
# 0.5913443454469121
# ---------
# CrossValMean AUC SCORE:
# 0.6256370586391272
# ---------
# CrossValMean AUC SCORE:
# 0.6333149460142447
# ---------
# CrossValMean AUC SCORE:
# 0.6609179075087092
# ---------
# CrossValMean AUC SCORE:
# 0.6044741845128614
# ---------
# CrossValMean AUC SCORE:
# 0.6432853619122044
# ---------
# CrossValMean AUC SCORE:
# 0.6236244213986735
# ---------
# CrossValMean AUC SCORE:
# 0.6334688576210592
# ---------
# CrossValMean AUC SCORE:
# 0.60408777849166
# ---------
# CrossValMean AUC SCORE:
# 0.6512616115449162
# ---------
# CrossValMean AUC SCORE:
# ...
# CrossValMean AUC SCORE:
# 0.6528134504520592
# ---------
# CrossValMean AUC SCORE:
# 0.6239811971355381
# ---------
# CrossValMean AUC SCORE:
# 0.5957778063038669
# ---------
# CrossValMean AUC SCORE:
# 0.6554611611133265
# ---------
# CrossValMean AUC SCORE:
# 0.6533968309427041
# ---------
# CrossValMean AUC SCORE:
# 0.6081671282889018
# ---------
# CrossValMean AUC SCORE:
# 0.6341227783677187
# ---------
# CrossValMean AUC SCORE:
# 0.638344171334159
# ---------
# CrossValMean AUC SCORE:
# 0.643872635633613
# ---------
# CrossValMean AUC SCORE:
# 0.6476418194373925
# ---------
# CrossValMean AUC SCORE:
# 0.6495053902472343
# ---------
# CrossValMean AUC SCORE:
# 0.6093598033237979
# ---------
# CrossValMean AUC SCORE:
# 0.6289891191583373
# ---------
# CrossValMean AUC SCORE:
# 0.6453513026602612
# ---------
# CrossValMean AUC SCORE:
# 0.6178083126092127
# ---------
# CrossValMean AUC SCORE:
# 0.6510882544473983
# ---------
# CrossValMean AUC SCORE:
# 0.6229800923036237
# ---------
# CrossValMean AUC SCORE:
# 0.6046323801273452
# ---------
# CrossValMean AUC SCORE:
# 0.627344378577646
# ---------
# CrossValMean AUC SCORE:
# 0.6002860658308109
# ---------
# CrossValMean AUC SCORE:
# 0.6300573020516229
# ---------
# CrossValMean AUC SCORE:
# 0.6199951546980871
# ---------
# CrossValMean AUC SCORE:
# 0.6609167569709804
# ---------
# CrossValMean AUC SCORE:
# 0.6192074762130886
# ---------
# CrossValMean AUC SCORE:
# 0.6469577746940851
# ---------
# CrossValMean AUC SCORE:
# 0.6464443373616139
# ---------
# CrossValMean AUC SCORE:
# 0.6262230937034693
# ---------
# CrossValMean AUC SCORE:
# 0.6662862605519347
# ---------
# CrossValMean AUC SCORE:
# 0.6216990856773077
# ---------
# CrossValMean AUC SCORE:
# 0.6274589106661521
# ---------
# CrossValMean AUC SCORE:
# 0.6640232091567777
# ---------
# CrossValMean AUC SCORE:
# 0.6615394125081251
# ---------
# CrossValMean AUC SCORE:
# 0.645218062105047
# ---------
# CrossValMean AUC SCORE:
# 0.6376489596377262
# 100%|████████████████████████████████████████████| 200/200 [1:29:05<00:00, 26.73s/trial, best loss: 0.3328703018192525]
# Best:  {'colsample_bytree': 0.41000000000000003, 'eta': 1.0, 'gamma': 0.02, 'learning_rate': 0.03, 'max_depth': 0, 'min_child_weight': 1.0, 'n_estimators': 7, 'reg_alpha': 169.0, 'reg_lambda': 0.11659690697151562, 'subsample': 0.31, 'tree_method': 1}
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[8], line 70
#      58 from xgboost import XGBClassifier
#      59 classifier = XGBClassifier(n_estimators = best['n_estimators'],
#      60                             max_depth = best['max_depth'],
#      61                             learning_rate = best['learning_rate'],
#    (...)
#      67                             tree_method = best['tree_method']
#      68                             )
# ---> 70 classifier.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:1515, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1487 (
#    1488     model,
#    1489     metric,
#    (...)
#    1494     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1495 )
#    1496 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1497     missing=self.missing,
#    1498     X=X,
#    (...)
#    1512     feature_types=self.feature_types,
#    1513 )
# -> 1515 self._Booster = train(
#    1516     params,
#    1517     train_dmatrix,
#    1518     self.get_num_boosting_rounds(),
#    1519     evals=evals,
#    1520     early_stopping_rounds=early_stopping_rounds,
#    1521     evals_result=evals_result,
#    1522     obj=obj,
#    1523     custom_metric=metric,
#    1524     verbose_eval=verbose,
#    1525     xgb_model=model,
#    1526     callbacks=callbacks,
#    1527 )
#    1529 if not callable(self.objective):
#    1530     self.objective = params["objective"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:2049, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
# -> 2049     _check_call(
#    2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:281, in _check_call(ret)
#     270 """Check the return value of C API call
#     271
#     272 This function will raise exception when error occurs.
#    (...)
#     278     return value from API calls
#     279 """
#     280 if ret != 0:
# --> 281     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: Invalid Input: '1', valid values are: {'approx', 'auto', 'exact', 'gpu_hist', 'hist'}

# %%
best_params = {'colsample_bytree': 0.5, 'eta': 0.8, 'gamma': 0.24, 'learning_rate': 0.04, 'max_depth': 5, 'min_child_weight': 4.0, 'n_estimators': 27, 'subsample': 0.75}


best_2 = {'colsample_bytree': 0.41000000000000003, 'eta': 1.0, 'gamma': 0.02, 'learning_rate': 0.03, 'max_depth': 0, 'min_child_weight': 1.0, 'n_estimators': 7, 'reg_alpha': 169.0, 'reg_lambda': 0.11659690697151562, 'subsample': 0.31, 'tree_method': 'hist'}

# %%
xgb_final_clf = XGBClassifier(**best_params)

# %%
fit_and_result(xgb_final_clf)
# Out:
# Точность на тренировочной выборке
# 0.601772899957788
# Точность на тестовой выборке
# 0.5995812791247384
#
#
# ROC AUC TEST: 0.6589

# %%
cross_val_score(estimator = xgb_final_clf, scoring='roc_auc', X = X_test, y = y_test, cv = 10)
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
