# %% [markdown]
# # Подготовка. Изучение данных

# %%
import pandas as pd
from IPython.display import HTML, display

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Сессии

# %%
# датафрейм сессий
# Одна строка = один визит на сайт.
sessions_df = pd.read_csv('data/ga_sessions.csv')
sessions_df
# Out:
# C:\Users\Nik\AppData\Local\Temp\ipykernel_13732\755692628.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   sessions_df = pd.read_csv('data/ga_sessions.csv')
#                                         session_id          client_id  \
# 0        9055434745589932991.1637753792.1637753792  2108382700.163776
# 1         905544597018549464.1636867290.1636867290   210838531.163687
# 2        9055446045651783499.1640648526.1640648526  2108385331.164065
# 3        9055447046360770272.1622255328.1622255328  2108385564.162225
# 4        9055447046360770272.1622255345.1622255345  2108385564.162225
# ...                                            ...                ...
# 1860037  9055415581448263752.1640159305.1640159305  2108378238.164016
# 1860038  9055421130527858185.1622007305.1622007305  2108379530.162201
# 1860039  9055422955903931195.1636979515.1636979515  2108379955.163697
# 1860040   905543020766873816.1638189404.1638189404   210838164.163819
# 1860041  9055430416266113553.1640968742.1640968742  2108381692.164097
#
#          visit_date visit_time  visit_number            utm_source utm_medium  \
# 0        2021-11-24   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1        2021-11-14   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2        2021-12-28   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 3        2021-05-29   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# 4        2021-05-29   05:00:00             2  kjsLglQLzykiRbcDiGcD        cpc
# ...             ...        ...           ...                   ...        ...
# 1860037  2021-12-22   10:48:25             1  BHcvLfOaCWvWTykYqHVe        cpc
# 1860038  2021-05-26   08:00:00             1  fDLlAcSmythWSCVMvqvL     (none)
# 1860039  2021-11-15   15:31:55             1  fDLlAcSmythWSCVMvqvL     (none)
# 1860040  2021-11-29   15:36:44             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1860041  2021-12-31   19:39:02             1  fgymSoTvjKPEgaIJqsiH        cpm
#
#                  utm_campaign         utm_adcontent           utm_keyword  \
# 0        LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 1        FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO  IGUCNvHlhfHpROGclCit
# 2        LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 3                         NaN  NOBKLgtuvqYWkXQHeYWM                   NaN
# 4                         NaN                   NaN                   NaN
# ...                       ...                   ...                   ...
# 1860037                   NaN                   NaN  VlqBmecIOXWjCWUmQkLd
# 1860038  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf                   NaN
# 1860039  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf  puhZPIYqKXeFPaUviSjo
# 1860040  LEoPHuyFvzoNfnzGgfcd  JNHcPlZPxEMWDnRiyoBf  puhZPIYqKXeFPaUviSjo
# 1860041  FTjNLDyTrXaWYgZymFkV  yYdBRbPmBMUZHXwqGxNx  oKjXDUsycmahkgMhGdAR
#
#         device_category device_os device_brand device_model  \
# 0                mobile   Android       Huawei          NaN
# 1                mobile   Android      Samsung          NaN
# 2                mobile   Android       Huawei          NaN
# 3                mobile       NaN       Xiaomi          NaN
# 4                mobile       NaN       Xiaomi          NaN
# ...                 ...       ...          ...          ...
# 1860037         desktop   Windows          NaN          NaN
# 1860038          mobile       NaN        Apple          NaN
# 1860039          mobile       iOS        Apple          NaN
# 1860040          mobile   Android       Xiaomi          NaN
# 1860041         desktop     Linux          NaN          NaN
#
#         device_screen_resolution    device_browser geo_country     geo_city
# 0                        360x720            Chrome      Russia     Zlatoust
# 1                        385x854  Samsung Internet      Russia       Moscow
# 2                        360x720            Chrome      Russia  Krasnoyarsk
# 3                        393x786            Chrome      Russia       Moscow
# 4                        393x786            Chrome      Russia       Moscow
# ...                          ...               ...         ...          ...
# 1860037                1920x1080            Chrome      Russia       Moscow
# 1860038                  390x844            Safari      Russia    Stavropol
# 1860039                  375x667            Safari      Russia       Moscow
# 1860040                  393x851            Chrome      Russia  Chelyabinsk
# 1860041                 1366x768            Chrome      Russia       Moscow
#
# [1860042 rows x 18 columns]

# %%
sessions_df.shape
# Out:
# (1860042, 18)

# %%
sessions_df.columns
# Out:
# Index(['session_id', 'client_id', 'visit_date', 'visit_time', 'visit_number',
#        'utm_source', 'utm_medium', 'utm_campaign', 'utm_adcontent',
#        'utm_keyword', 'device_category', 'device_os', 'device_brand',
#        'device_model', 'device_screen_resolution', 'device_browser',
#        'geo_country', 'geo_city'],
#       dtype='object')

# %%
sessions_df.describe(include='all')
# Out:
#                                        session_id     client_id  visit_date  \
# count                                     1860042  1.860042e+06     1860042
# unique                                    1860042  1.391717e+06         226
# top     9055434745589932991.1637753792.1637753792  1.750498e+09  2021-05-24
# freq                                            1  4.620000e+02       39453
# mean                                          NaN           NaN         NaN
# std                                           NaN           NaN         NaN
# min                                           NaN           NaN         NaN
# 25%                                           NaN           NaN         NaN
# 50%                                           NaN           NaN         NaN
# 75%                                           NaN           NaN         NaN
# max                                           NaN           NaN         NaN
#
#        visit_time  visit_number            utm_source utm_medium  \
# count     1860042  1.860042e+06               1859945    1860042
# unique      85318           NaN                   293         56
# top      12:00:00           NaN  ZpYIoDJMcFzVoPFsHGJL     banner
# freq        61067           NaN                578290     552272
# mean          NaN  2.712804e+00                   NaN        NaN
# std           NaN  1.182907e+01                   NaN        NaN
# min           NaN  1.000000e+00                   NaN        NaN
# 25%           NaN  1.000000e+00                   NaN        NaN
# 50%           NaN  1.000000e+00                   NaN        NaN
# 75%           NaN  2.000000e+00                   NaN        NaN
# max           NaN  5.640000e+02                   NaN        NaN
#
#                 utm_campaign         utm_adcontent           utm_keyword  \
# count                1640439               1524427                777981
# unique                   412                   286                  1219
# top     LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf  puhZPIYqKXeFPaUviSjo
# freq                  463481               1006599                506819
# mean                     NaN                   NaN                   NaN
# std                      NaN                   NaN                   NaN
# min                      NaN                   NaN                   NaN
# 25%                      NaN                   NaN                   NaN
# 50%                      NaN                   NaN                   NaN
# 75%                      NaN                   NaN                   NaN
# max                      NaN                   NaN                   NaN
#
#        device_category device_os device_brand          device_model  \
# count          1860042    789904      1492864                 16338
# unique               3        13          205                   104
# top             mobile   Android        Apple  AuMdmADEIoPXiWpTsBEj
# freq           1474871    464054       551088                  9778
# mean               NaN       NaN          NaN                   NaN
# std                NaN       NaN          NaN                   NaN
# min                NaN       NaN          NaN                   NaN
# 25%                NaN       NaN          NaN                   NaN
# 50%                NaN       NaN          NaN                   NaN
# 75%                NaN       NaN          NaN                   NaN
# max                NaN       NaN          NaN                   NaN
#
#        device_screen_resolution device_browser geo_country geo_city
# count                   1860042        1860042     1860042  1860042
# unique                     5039             57         166     2548
# top                     414x896         Chrome      Russia   Moscow
# freq                     169090        1013436     1800565   805329
# mean                        NaN            NaN         NaN      NaN
# std                         NaN            NaN         NaN      NaN
# min                         NaN            NaN         NaN      NaN
# 25%                         NaN            NaN         NaN      NaN
# 50%                         NaN            NaN         NaN      NaN
# 75%                         NaN            NaN         NaN      NaN
# max                         NaN            NaN         NaN      NaN

# %%
sessions_df.dtypes
# Out:
# session_id                  object
# client_id                   object
# visit_date                  object
# visit_time                  object
# visit_number                 int64
# utm_source                  object
# utm_medium                  object
# utm_campaign                object
# utm_adcontent               object
# utm_keyword                 object
# device_category             object
# device_os                   object
# device_brand                object
# device_model                object
# device_screen_resolution    object
# device_browser              object
# geo_country                 object
# geo_city                    object
# dtype: object

# %% [markdown]
# ## События

# %%
# датафрейм событий
# Одна строка = одно событие в рамках одного визита на сайтv
hits_df = pd.read_csv('data/ga_hits.csv')
hits_df
# Out:
#                                          session_id    hit_date   hit_time  \
# 0         5639623078712724064.1640254056.1640254056  2021-12-23   597864.0
# 1         7750352294969115059.1640271109.1640271109  2021-12-23   597331.0
# 2          885342191847998240.1640235807.1640235807  2021-12-23   796252.0
# 3          142526202120934167.1640211014.1640211014  2021-12-23   934292.0
# 4         3450086108837475701.1640265078.1640265078  2021-12-23   768741.0
# ...                                             ...         ...        ...
# 15726465  6866159858916559617.1640270865.1640270865  2021-12-23   810589.0
# 15726466  7310304587364460692.1640261783.1640261783  2021-12-23   904927.0
# 15726467  8013702685784312179.1640270195.1640270195  2021-12-23  2172865.0
# 15726468  8021505554734405918.1640257821.1640257821  2021-12-23   713325.0
# 15726469  1569014437485249865.1640269129.1640269129  2021-12-23   742820.0
#
#           hit_number hit_type hit_referer  \
# 0                 30    event         NaN
# 1                 41    event         NaN
# 2                 49    event         NaN
# 3                 46    event         NaN
# 4                 79    event         NaN
# ...              ...      ...         ...
# 15726465          43    event         NaN
# 15726466          40    event         NaN
# 15726467          43    event         NaN
# 15726468          45    event         NaN
# 15726469          46    event         NaN
#
#                                               hit_page_path event_category  \
# 0         sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1         sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2         sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
# 3         sberauto.com/cars?utm_source_initial=yandex&ut...           quiz
# 4         sberauto.com/cars/all/mercedes-benz/cla-klasse...           quiz
# ...                                                     ...            ...
# 15726465  sberauto.com/cars/all/toyota/fortuner/24cb5af2...           quiz
# 15726466  sberauto.com/cars/all/mercedes-benz/gla-klasse...           quiz
# 15726467  sberauto.com/cars/all/toyota/alphard/2ebe4871?...           quiz
# 15726468  sberauto.com/cars/all/bmw/x3/6a660f0a?rental_p...           quiz
# 15726469  sberauto.com/cars/all/bmw/7-serii/399ac530?utm...           quiz
#
#          event_action event_label  event_value
# 0           quiz_show         NaN          NaN
# 1           quiz_show         NaN          NaN
# 2           quiz_show         NaN          NaN
# 3           quiz_show         NaN          NaN
# 4           quiz_show         NaN          NaN
# ...               ...         ...          ...
# 15726465    quiz_show         NaN          NaN
# 15726466    quiz_show         NaN          NaN
# 15726467    quiz_show         NaN          NaN
# 15726468    quiz_show         NaN          NaN
# 15726469    quiz_show         NaN          NaN
#
# [15726470 rows x 11 columns]

# %%
hits_df.shape
# Out:
# (15726470, 11)

# %%
hits_df.columns
# Out:
# Index(['session_id', 'hit_date', 'hit_time', 'hit_number', 'hit_type',
#        'hit_referer', 'hit_page_path', 'event_category', 'event_action',
#        'event_label', 'event_value'],
#       dtype='object')

# %%
hits_df.describe(include='all')
# Out:
#                                        session_id    hit_date      hit_time  \
# count                                    15726470    15726470  6.566148e+06
# unique                                    1734610         226           NaN
# top     5442565791571325612.1632449195.1632449195  2021-05-24           NaN
# freq                                          768      513035           NaN
# mean                                          NaN         NaN  2.091050e+05
# std                                           NaN         NaN  4.032110e+05
# min                                           NaN         NaN  0.000000e+00
# 25%                                           NaN         NaN  2.412000e+04
# 50%                                           NaN         NaN  8.994100e+04
# 75%                                           NaN         NaN  2.195352e+05
# max                                           NaN         NaN  1.315688e+07
#
#           hit_number  hit_type           hit_referer           hit_page_path  \
# count   1.572647e+07  15726470               9451666                15726470
# unique           NaN         1                 37873                  342715
# top              NaN     event  HbolMJUevblAbkHClEQa  podpiska.sberauto.com/
# freq             NaN  15726470               8879187                 2793639
# mean    2.356715e+01       NaN                   NaN                     NaN
# std     2.887713e+01       NaN                   NaN                     NaN
# min     1.000000e+00       NaN                   NaN                     NaN
# 25%     7.000000e+00       NaN                   NaN                     NaN
# 50%     1.500000e+01       NaN                   NaN                     NaN
# 75%     2.900000e+01       NaN                   NaN                     NaN
# max     5.000000e+02       NaN                   NaN                     NaN
#
#        event_category event_action           event_label  event_value
# count        15726470     15726470              11966286          0.0
# unique             52          230                 39825          NaN
# top          card_web    view_card  KclpemfoHstknWHFiLit          NaN
# freq          7456998      3558985               6505447          NaN
# mean              NaN          NaN                   NaN          NaN
# std               NaN          NaN                   NaN          NaN
# min               NaN          NaN                   NaN          NaN
# 25%               NaN          NaN                   NaN          NaN
# 50%               NaN          NaN                   NaN          NaN
# 75%               NaN          NaN                   NaN          NaN
# max               NaN          NaN                   NaN          NaN

# %%
hits_df.dtypes
# Out:
# session_id         object
# hit_date           object
# hit_time          float64
# hit_number          int64
# hit_type           object
# hit_referer        object
# hit_page_path      object
# event_category     object
# event_action       object
# event_label        object
# event_value       float64
# dtype: object

# %% [markdown]
#  ## Объединяем данные

# %%
merged_df = sessions_df.merge(hits_df, how='inner', on='session_id')
merged_df

merged_df.to_csv('processed_data/full_merged.csv')


merged_df = merged_df.sample(frac = 0.01, random_state = 200)

# %%
hits_df = sessions_df = None
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Очистка данных

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156852 entries, 11640074 to 1449787
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   session_id                156852 non-null  object
#  1   client_id                 156852 non-null  object
#  2   visit_date                156852 non-null  object
#  3   visit_time                156852 non-null  object
#  4   visit_number              156852 non-null  int64
#  5   utm_source                156840 non-null  object
#  6   utm_medium                156852 non-null  object
#  7   utm_campaign              134763 non-null  object
#  8   utm_adcontent             128501 non-null  object
#  9   utm_keyword               64884 non-null   object
#  10  device_category           156852 non-null  object
#  11  device_os                 65335 non-null   object
#  12  device_brand              117458 non-null  object
#  13  device_model              1197 non-null    object
#  14  device_screen_resolution  156852 non-null  object
#  15  device_browser            156852 non-null  object
#  16  geo_country               156852 non-null  object
#  17  geo_city                  156852 non-null  object
#  18  hit_date                  156852 non-null  object
#  19  hit_time                  65346 non-null   float64
#  20  hit_number                156852 non-null  int64
#  21  hit_type                  156852 non-null  object
#  22  hit_referer               94414 non-null   object
#  23  hit_page_path             156852 non-null  object
#  24  event_category            156852 non-null  object
#  25  event_action              156852 non-null  object
#  26  event_label               119674 non-null  object
#  27  event_value               0 non-null       float64
# dtypes: float64(2), int64(2), object(24)
# memory usage: 34.7+ MB

# %%
def print_columns_with_skipped_values(df):
    skipped_values_in_percents = ((df.isna().sum() / len(df)) * 100).sort_values()
    display(skipped_values_in_percents[skipped_values_in_percents > 0.0])
    return skipped_values_in_percents[skipped_values_in_percents > 0.0].index.tolist()

# %%
list_columns_with_skipped_values = print_columns_with_skipped_values(merged_df)
# Out:
# utm_source         0.007651
# utm_campaign      14.082702
# utm_adcontent     18.075001
# event_label       23.702599
# device_brand      25.115395
# hit_referer       39.806952
# hit_time          58.339071
# device_os         58.346084
# utm_keyword       58.633616
# device_model      99.236860
# event_value      100.000000
# dtype: float64

# %%
list_columns_with_skipped_values
# Out:
# ['utm_source',
#  'utm_campaign',
#  'utm_adcontent',
#  'event_label',
#  'device_brand',
#  'hit_referer',
#  'hit_time',
#  'device_os',
#  'utm_keyword',
#  'device_model',
#  'event_value']

# %%
for column in list_columns_with_skipped_values:
    display(f'column ----------------------- {column}')
    display(f'unique num: {merged_df[column].nunique()}')
    display(merged_df[column].value_counts())
# Out:
# 'column ----------------------- utm_source'
# 'unique num: 147'
# ZpYIoDJMcFzVoPFsHGJL    51450
# fDLlAcSmythWSCVMvqvL    32285
# kjsLglQLzykiRbcDiGcD    17753
# bByPQxmDaMXgpHeypKSM    13500
# BHcvLfOaCWvWTykYqHVe    12330
#                         ...
# woJzIcuFapkhnraMjtKA        1
# rHNgiupMNBtKyhTaWxJY        1
# FNIjOzNNxWDHGSGhdwpo        1
# rgsINTLYFsElIlfRtNDP        1
# MEitHbTnBcZIHbJvtCyh        1
# Name: utm_source, Length: 147, dtype: int64
# 'column ----------------------- utm_campaign'
# 'unique num: 300'
# LTuZkdKfxRGVceoWkVyg    51461
# LEoPHuyFvzoNfnzGgfcd    31685
# gecBYcKZCPMcVYdSSzKP    11509
# FTjNLDyTrXaWYgZymFkV     7506
# okTXSMadDkjvntEHzIjp     1834
#                         ...
# enrUjlPmoRCCSQCEJpCp        1
# RmEBuqrriAfAVsLQQmhk        1
# zeAhgziIlupwjQfwRisw        1
# pZusNNTculJrJpXVbetv        1
# YpBKcihLLfFjWuxOLfvW        1
# Name: utm_campaign, Length: 300, dtype: int64
# 'column ----------------------- utm_adcontent'
# 'unique num: 170'
# JNHcPlZPxEMWDnRiyoBf    96429
# vCIpmpaGBnIQhyYNkXqp    18085
# xhoenQgDQsgfEPYNPwKO     3486
# PkybGvWbaqORmxjNunqZ     1945
# LLfCasrxQzJIyuldcuWy     1793
#                         ...
# bOQwsecsGWEGaGQIaBDu        1
# fbySNkOYEQozwDJXwjPd        1
# QccYUpzJHdpDeTampwlw        1
# MObjlMmvbpXSMcuLcoAX        1
# WyligyAVjsWBDjaYTidY        1
# Name: utm_adcontent, Length: 170, dtype: int64
# 'column ----------------------- event_label'
# 'unique num: 2238'
# KclpemfoHstknWHFiLit    64932
# hAHqGICPFQiPwtzubOzs    12936
# OHfyUfDKdPgBdvelDlfG     6219
# pzAKUYdRKNEUXxxBFUPX     3620
# ghOrjqpgskpGHSFfBBsi     3405
#                         ...
# hBLlufNAdsRLjuvYhmTx        1
# ButalBJflpHQWgOSgOaA        1
# jSpEJsNEmmjBDPnmEAOK        1
# SjSBrMEOIEnCxjJQVrRX        1
# XHEqCJQpfrmiMKqJAozo        1
# Name: event_label, Length: 2238, dtype: int64
# 'column ----------------------- device_brand'
# 'unique num: 91'
# Apple           47019
# Samsung         26097
# Xiaomi          20764
# Huawei          13671
# Realme           1413
#                 ...
# Dragon Touch        1
# Gionee              1
# Nomu                1
# Beelink             1
# Nuu                 1
# Name: device_brand, Length: 91, dtype: int64
# 'column ----------------------- hit_referer'
# 'unique num: 1901'
# HbolMJUevblAbkHClEQa    88684
# FwdMTcXzWAwhtsnMAbhS      944
# sAGDBCdeVPmQPwkVEcIX      519
# GQmOLxANuSeCxCanBpMl      366
# ZeRnFrHdnMmnqraghdGJ      241
#                         ...
# HRzzkGijjapCreYebAAH        1
# wXMrVvNiQqjioaMttwag        1
# MejvMuhyJoWhlhqgNdhK        1
# fLfyTVPNGodIvFFqPXHv        1
# bbceYxdPMwDpOGmdnkbd        1
# Name: hit_referer, Length: 1901, dtype: int64
# 'column ----------------------- hit_time'
# 'unique num: 53990'
# 0.0         382
# 1.0         192
# 2.0         109
# 3.0          62
# 4.0          43
#            ...
# 9071.0        1
# 199564.0      1
# 322379.0      1
# 521782.0      1
# 419887.0      1
# Name: hit_time, Length: 53990, dtype: int64
# 'column ----------------------- device_os'
# 'unique num: 8'
# Android       34393
# iOS           17312
# Windows       10140
# Macintosh      3161
# Linux           311
# Chrome OS         9
# (not set)         5
# BlackBerry        4
# Name: device_os, dtype: int64
# 'column ----------------------- utm_keyword'
# 'unique num: 626'
# puhZPIYqKXeFPaUviSjo    47164
# aXQzDWsJuGXeBXexNHjc     1798
# ITfrGJNwVsHBGJMAKoct     1446
# UKNBOHebRIIsQRsjNKay     1340
# hAmNSZmQkKQKAjZEGlgb      992
#                         ...
# vBgJsvsqiUSnOEyphSkB        1
# viJRyeJfSPaqDtxzXuOp        1
# ZHCJROlbqnkXTqIuVxnm        1
# VALiRqDzMPBJaHJPtKTI        1
# bZGRDuESNKqbvzmxXlpf        1
# Name: utm_keyword, Length: 626, dtype: int64
# 'column ----------------------- device_model'
# 'unique num: 60'
# AuMdmADEIoPXiWpTsBEj    728
# tWBQlsvNfHxRUjaPAfhd     56
# cwMJxNXiWUgMUxGiCTPs     37
# pTgAEPipQxDXCjPrJbHo     32
# pcvPxfVFaAmhwFmvIeYd     29
# FJApgTrMAGHoxCxQVKws     25
# mzJXHtJPIOSHoHtgezIA     24
# tfPZFRbtlzEssBEesRwM     22
# aCLaTVQlHcXbUnQYQvIg     18
# zFCiMWkbbAhTflrlLWnz     17
# jXFxTkHxuiBKWOvUtsIa     13
# OSucmOyBXEpHCUNRuhuN     11
# rTksOeVOQqJRyKCjcexB     11
# JAIKWwxRffFOXQcfGTVi     11
# phrsMxwuvNvYsPYNbKkL      9
# ciZAODXEPQGDKvuEabGr      9
# WjsFbaSQmnGghVzNcrpJ      9
# DzXtLnggNbQSyyFLKlgY      9
# AshpvdJdReafUzEMmWGr      8
# ZkRlaMsFhSBPslXBtfiG      7
# WYZTTdhWPjttFYmcGjBP      7
# auOrYtJwDXWlMwuBxhRC      6
# mSVMBvlHFgftJaQAZEdp      6
# HYwfQOXoovXynCsiUCVd      6
# wsPZygnUifLMgkSEnWLj      6
# QIKziXyAufrHMzeBTtlI      5
# IiVVIXFnNMwpBtuHILvS      5
# qBRdfuuhOnnqwSqNiPOv      4
# EEnoZBXHUTLQhNvTLYel      4
# YyqUacVclbjfhEXffQFl      4
# ftFxnRDRijjFNnJoXPMw      4
# jWdGMEVrJZkHcVcJFAda      4
# bZGRDuESNKqbvzmxXlpf      4
# bwQQjmDtGgrbnrREsYSG      3
# CwplVZElsIzdKfSTHwma      3
# QIRMJBHwssjlXzlheRfO      3
# oLPSmNOyoeTqtTUhnNIq      3
# xZYEHLyYdGXkJENJpTtu      3
# BhXucgFEfQMgSWpyKikP      3
# zjEebiuHyqSWFKMwbgwQ      2
# KUROllwAYyecYcjFOgAi      2
# kjULrCjbRVbJtOfWpmQI      2
# gHPFJHVEyWmOlsGSbywQ      2
# qAQjHpYoRUxgMseGGEfL      2
# opEZzhCrCCxqjKDmOcMK      2
# wOpkmMMUmanXnzWXmcFq      2
# JGctjjnHmHZeOLjBUdBa      2
# NGNkCWwKgYFmiCCeZVxg      1
# ZCFvDdRaCVwsuCIbnPOf      1
# FMeAKypVmqdjUhayrjne      1
# CHEgAchdlTbIOcHAYzGk      1
# FTAuYVNoYYxgvKMpKSLW      1
# ifwJecAlGiEmDdqlxOfb      1
# lhoYkemXATyKyUwRAztp      1
# WpQWiuxAzSOBVgxHHdIY      1
# hSzHgWXfOZhXwHXOrXgd      1
# XoFyyEyrxZQbFrIVBGJU      1
# sLQbYFRIWJPmCqXsQgTS      1
# QzPMrfYhYSLYYPtPaBxI      1
# kGgpyeEtacYWhzbuuWMR      1
# Name: device_model, dtype: int64
# 'column ----------------------- event_value'
# 'unique num: 0'
# Series([], Name: event_value, dtype: int64)

# %%
## удаляем неинформативные колонки и колонки с большим количеством пропусков

# %%
merged_df=merged_df.drop(['event_value','utm_keyword', 'hit_referer', 'event_label', 'utm_adcontent', 'utm_campaign', 'utm_source', # неинформативные
                          'hit_time', 'device_os','device_model','device_brand',
                         'hit_type', 'hit_date'], axis=1) # hit type - содержит единственное значение, hit-date избыточно без hit_time
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156852 entries, 11640074 to 1449787
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   session_id                156852 non-null  object
#  1   client_id                 156852 non-null  object
#  2   visit_date                156852 non-null  object
#  3   visit_time                156852 non-null  object
#  4   visit_number              156852 non-null  int64
#  5   utm_medium                156852 non-null  object
#  6   device_category           156852 non-null  object
#  7   device_screen_resolution  156852 non-null  object
#  8   device_browser            156852 non-null  object
#  9   geo_country               156852 non-null  object
#  10  geo_city                  156852 non-null  object
#  11  hit_number                156852 non-null  int64
#  12  hit_page_path             156852 non-null  object
#  13  event_category            156852 non-null  object
#  14  event_action              156852 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 19.1+ MB

# %%
print_columns_with_skipped_values(merged_df)
# Out:
# Series([], dtype: float64)
# []

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156852 entries, 11640074 to 1449787
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   session_id                156852 non-null  object
#  1   client_id                 156852 non-null  object
#  2   visit_date                156852 non-null  object
#  3   visit_time                156852 non-null  object
#  4   visit_number              156852 non-null  int64
#  5   utm_medium                156852 non-null  object
#  6   device_category           156852 non-null  object
#  7   device_screen_resolution  156852 non-null  object
#  8   device_browser            156852 non-null  object
#  9   geo_country               156852 non-null  object
#  10  geo_city                  156852 non-null  object
#  11  hit_number                156852 non-null  int64
#  12  hit_page_path             156852 non-null  object
#  13  event_category            156852 non-null  object
#  14  event_action              156852 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 19.1+ MB

# %% [markdown]
# # Удаляем дубликаты

# %%
merged_df[merged_df.duplicated()]
# Out:
#                                          session_id              client_id  \
# 15219516  8805904515850871015.1632411891.1632411891      2050284416.163241
# 10068882  6082785616851569737.1632308298.1632308298  1416258890.1632308297
# 13979129  8150283629336636246.1632283479.1632283479      1897635783.163229
# 7209386   4576754136213464777.1632478921.1632478921      1065608611.163248
# 14645858  8504095385844415859.1632337268.1632337268      1980014002.163234
# 2064442   1853472397824108820.1632381207.1632381207   431545171.1632381204
# 14777097  8571641988616388620.1632469004.1632469004      1995740921.163247
# 13771412  8041774046562266813.1632415420.1632415420      1872371427.163241
# 12924046  7588689506896410940.1632336085.1632336085      1766879462.163234
# 836780    1199095290889183720.1632313832.1632313832   279186128.1632313832
# 6077063   3980042948116796782.1632425326.1632425326       926675961.163242
# 5281008    354991203404185625.1632337945.1632337945        82652830.163234
# 6396380   4147247429404424684.1632467440.1632467440       965606288.163247
# 9444461   5753044351719354490.1632415866.1632415866      1339485019.163242
# 1915667   1771565060797064340.1632461832.1632461832   412474633.1632461972
# 4149296   2956496084782458592.1632282321.1632282321       688362886.163228
# 14574059  8466360911283286103.1632301143.1632301143       1971228260.16323
# 2883679   2292579537655819886.1632497262.1632497262   533782769.1632497262
#
#           visit_date visit_time  visit_number utm_medium device_category  \
# 15219516  2021-09-23   18:00:00             1     banner          mobile
# 10068882  2021-09-22   13:00:00             1        cpc          mobile
# 13979129  2021-09-22   07:04:39             1        cpm          mobile
# 7209386   2021-09-24   13:22:01             1        cpc          mobile
# 14645858  2021-09-22   22:01:08             1     banner          mobile
# 2064442   2021-09-23   10:00:00             1        cpc          mobile
# 14777097  2021-09-24   10:36:44             1     (none)         desktop
# 13771412  2021-09-23   19:43:40             1        cpc         desktop
# 12924046  2021-09-22   21:00:00             1        cpc          mobile
# 836780    2021-09-22   15:00:00             1        cpc          mobile
# 6077063   2021-09-23   22:00:00             1     (none)          mobile
# 5281008   2021-09-22   22:12:25             1        cpc          mobile
# 6396380   2021-09-24   10:10:40             1     (none)         desktop
# 9444461   2021-09-23   19:00:00             1     (none)          mobile
# 1915667   2021-09-24   08:00:00             1        cpc          mobile
# 4149296   2021-09-22   06:00:00             1     banner          mobile
# 14574059  2021-09-22   11:00:00             1        cpc          mobile
# 2883679   2021-09-24   18:27:42             1     banner          mobile
#
#          device_screen_resolution device_browser geo_country  \
# 15219516                  393x851         Chrome      Russia
# 10068882                  360x760         Chrome      Russia
# 13979129                  851x393         Chrome      Russia
# 7209386                   375x667      YaBrowser      Russia
# 14645858                  412x892         Chrome      Russia
# 2064442                   412x915         Chrome      Russia
# 14777097                 1366x768      YaBrowser      Russia
# 13771412                 1366x768         Chrome      Russia
# 12924046                  393x851          Opera      Russia
# 836780                    375x667         Safari      Russia
# 6077063                   393x851         Chrome      Russia
# 5281008                   412x618         Chrome      Russia
# 6396380                 1920x1080        Firefox      Russia
# 9444461                   428x926         Safari      Russia
# 1915667                   360x640         Chrome      Russia
# 4149296                   424x942         Chrome      Russia
# 14574059                  412x915         Chrome      Russia
# 2883679                   375x812         Safari      Russia
#
#                   geo_city  hit_number  \
# 15219516            Moscow          29
# 10068882            Moscow          46
# 13979129            Moscow           3
# 7209386             Moscow          20
# 14645858            Moscow          66
# 2064442             Moscow           2
# 14777097            Uchaly          15
# 13771412        Volgodonsk           6
# 12924046  Saint Petersburg           6
# 836780                 Ufa           3
# 6077063             Lobnya           4
# 5281008          Lytkarino           4
# 6396380           Orenburg          53
# 9444461             Moscow          28
# 1915667             Moscow           4
# 4149296             Moscow           4
# 14574059     Yekaterinburg           6
# 2883679             Moscow           4
#
#                                               hit_page_path    event_category  \
# 15219516  sberauto.com/cars/6afb1543?utm_source_initial=...          card_web
# 10068882  sberauto.com/cars/6afb1543?utm_source_initial=...          card_web
# 13979129                             podpiska.sberauto.com/     sub_page_view
# 7209386   sberauto.com/cars/2fc745ed?rental_page=rental_car          card_web
# 14645858  sberauto.com/cars?utm_source_initial=sbol&utm_...       listing_ads
# 2064442   sberauto.com/cars/6afb1543?rental_page=rental_car          card_web
# 14777097  sberauto.com/cars/e994838f?rental_page=rental_car          card_web
# 13771412  sberauto.com/cars/bfc21661?rental_page=rental_car          card_web
# 12924046  sberauto.com/cars/2fc745ed?rental_page=rental_car          card_web
# 836780    sberauto.com/cars/2fc745ed?rental_page=rental_car          card_web
# 6077063   sberauto.com/cars/0d1e3352?rental_page=rental_car          card_web
# 5281008   sberauto.com/cars/6afb1543?rental_page=rental_car          card_web
# 6396380   sberauto.com/cars/eb5698f6?rental_page=rental_car          card_web
# 9444461   sberauto.com/cars/e994838f?rental_page=rental_car          card_web
# 1915667   sberauto.com/cars/6afb1543?rental_page=rental_car          card_web
# 4149296                              podpiska.sberauto.com/  sub_button_click
# 14574059  sberauto.com/cars/bfc21661?rental_page=rental_car          card_web
# 2883679                              podpiska.sberauto.com/  sub_button_click
#
#                  event_action
# 15219516        view_new_card
# 10068882            view_card
# 13979129          sub_landing
# 7209386         view_new_card
# 14645858       go_to_car_card
# 2064442         view_new_card
# 14777097            view_card
# 13771412        view_new_card
# 12924046        view_new_card
# 836780          view_new_card
# 6077063         view_new_card
# 5281008         view_new_card
# 6396380         view_new_card
# 9444461         view_new_card
# 1915667             view_card
# 4149296   sub_view_cars_click
# 14574059        view_new_card
# 2883679   sub_view_cars_click

# %%
merged_df = merged_df.drop_duplicates()
merged_df.shape
# Out:
# (156834, 15)

# %% [markdown]
# # Преобразование данных

# %%
column_names = merged_df.columns.tolist()
column_names
# Out:
# ['session_id',
#  'client_id',
#  'visit_date',
#  'visit_time',
#  'visit_number',
#  'utm_medium',
#  'device_category',
#  'device_screen_resolution',
#  'device_browser',
#  'geo_country',
#  'geo_city',
#  'hit_number',
#  'hit_page_path',
#  'event_category',
#  'event_action']

# %%
for column in column_names:
    display(f'------ {column} ------')
    display(merged_df[column].unique())
    display(merged_df[column].nunique())
# Out:
# '------ session_id ------'
# array(['6914769160598479845.1632396262.1632396262',
#        '496453351534802252.1640788638.1640788638',
#        '234484647397443835.1634224382.1634224382', ...,
#        '3624796273103333147.1635510044.1635510044',
#        '7683576630226201306.1629525600.1629525600',
#        '1527645312481816566.1632121142.1632121142'], dtype=object)
# 137668
# '------ client_id ------'
# array([1609970154.1632397, 115589553.16405436, '54595211.1634224379', ...,
#        843963649.1635511, 1788972092.1629498, 355682641.1631908],
#       dtype=object)
# 127644
# '------ visit_date ------'
# array(['2021-09-23', '2021-12-29', '2021-10-14', '2021-08-17',
#        '2021-09-05', '2021-10-26', '2021-09-21', '2021-11-07',
#        '2021-05-28', '2021-10-16', '2021-06-28', '2021-11-20',
#        '2021-06-13', '2021-09-03', '2021-11-24', '2021-11-03',
#        '2021-11-02', '2021-05-30', '2021-07-10', '2021-10-27',
#        '2021-07-19', '2021-12-03', '2021-05-27', '2021-10-24',
#        '2021-07-06', '2021-05-24', '2021-10-28', '2021-10-18',
#        '2021-07-11', '2021-06-27', '2021-08-29', '2021-12-14',
#        '2021-09-24', '2021-06-22', '2021-07-16', '2021-11-11',
#        '2021-05-26', '2021-11-01', '2021-11-22', '2021-09-15',
#        '2021-10-21', '2021-12-21', '2021-05-25', '2021-06-14',
#        '2021-10-23', '2021-07-01', '2021-12-22', '2021-11-30',
#        '2021-10-15', '2021-12-18', '2021-12-17', '2021-07-18',
#        '2021-12-08', '2021-09-13', '2021-12-31', '2021-06-12',
#        '2021-12-16', '2021-08-23', '2021-06-15', '2021-09-02',
#        '2021-12-07', '2021-07-21', '2021-11-21', '2021-06-23',
#        '2021-10-20', '2021-12-19', '2021-11-06', '2021-06-29',
#        '2021-07-20', '2021-09-30', '2021-10-13', '2021-06-03',
#        '2021-07-14', '2021-09-14', '2021-11-16', '2021-10-03',
#        '2021-12-28', '2021-06-09', '2021-12-20', '2021-11-13',
#        '2021-11-17', '2021-06-11', '2021-09-12', '2021-10-05',
#        '2021-08-21', '2021-08-31', '2021-12-26', '2021-09-22',
#        '2021-09-04', '2021-12-25', '2021-10-17', '2021-10-10',
#        '2021-11-19', '2021-09-26', '2021-12-10', '2021-11-14',
#        '2021-10-25', '2021-12-24', '2021-08-06', '2021-11-18',
#        '2021-08-24', '2021-11-27', '2021-08-10', '2021-11-12',
#        '2021-10-01', '2021-10-06', '2021-06-21', '2021-11-15',
#        '2021-12-06', '2021-07-05', '2021-12-27', '2021-08-03',
#        '2021-08-13', '2021-07-22', '2021-09-29', '2021-10-19',
#        '2021-08-09', '2021-11-05', '2021-08-05', '2021-05-19',
#        '2021-09-25', '2021-07-17', '2021-10-07', '2021-09-07',
#        '2021-10-29', '2021-08-28', '2021-12-05', '2021-12-09',
#        '2021-08-16', '2021-06-16', '2021-06-20', '2021-11-25',
#        '2021-08-02', '2021-07-04', '2021-07-30', '2021-10-31',
#        '2021-09-28', '2021-07-29', '2021-10-11', '2021-11-09',
#        '2021-12-04', '2021-09-01', '2021-12-02', '2021-12-30',
#        '2021-06-17', '2021-12-12', '2021-11-26', '2021-08-20',
#        '2021-10-30', '2021-12-01', '2021-06-30', '2021-07-08',
#        '2021-08-25', '2021-11-29', '2021-06-08', '2021-12-15',
#        '2021-07-28', '2021-06-19', '2021-08-12', '2021-05-31',
#        '2021-06-02', '2021-07-02', '2021-07-27', '2021-10-08',
#        '2021-09-20', '2021-11-04', '2021-09-18', '2021-05-23',
#        '2021-09-27', '2021-09-16', '2021-07-25', '2021-08-08',
#        '2021-08-27', '2021-07-26', '2021-09-17', '2021-07-03',
#        '2021-08-18', '2021-08-30', '2021-08-04', '2021-07-13',
#        '2021-07-12', '2021-12-23', '2021-06-24', '2021-06-06',
#        '2021-10-22', '2021-11-10', '2021-10-02', '2021-12-13',
#        '2021-08-26', '2021-09-08', '2021-11-08', '2021-09-10',
#        '2021-05-21', '2021-07-15', '2021-07-09', '2021-09-11',
#        '2021-07-24', '2021-06-01', '2021-08-19', '2021-06-04',
#        '2021-10-09', '2021-08-22', '2021-09-06', '2021-08-11',
#        '2021-08-07', '2021-09-19', '2021-06-05', '2021-06-18',
#        '2021-06-26', '2021-08-15', '2021-07-23', '2021-06-25',
#        '2021-07-31', '2021-12-11', '2021-08-14', '2021-06-07',
#        '2021-05-22', '2021-07-07', '2021-05-29', '2021-06-10',
#        '2021-09-09', '2021-10-12', '2021-10-04', '2021-08-01',
#        '2021-11-28', '2021-11-23'], dtype=object)
# 226
# '------ visit_time ------'
# array(['14:00:00', '17:37:18', '18:00:00', ..., '06:15:55', '07:22:02',
#        '12:15:13'], dtype=object)
# 39789
# '------ visit_number ------'
# array([  1,  16,   2,   4,   9,  10,   3,   5,  11,  66,  54,   7,  23,
#          6,   8,  60, 110,  15,  17,  18,  51,  63,  30,  27,  13,  19,
#         29,  49,  61,  36,  46, 146,  38,  21, 309,  14,  12,  87,  95,
#         83,  20, 111, 139,  34,  70, 505,  48,  42,  74, 158,  31, 127,
#         22,  26,  33, 284, 308,  55, 131, 507, 283,  25,  78,  24,  72,
#         39, 125, 262,  75,  52,  62,  76, 104,  28,  35,  58,  79,  41,
#        135, 277,  73, 100,  92, 108,  97, 116, 246,  71,  85,  88,  67,
#        160, 222,  80, 268,  44, 376,  84, 245,  37,  86,  45, 236,  47,
#         59, 199, 161, 240,  91, 128,  93, 174, 130,  56,  32,  43,  40,
#        223,  98, 167, 151, 186,  69,  53, 124,  77, 302, 474,  90, 137,
#        109, 106,  82, 154, 101, 202,  99, 162,  50, 192, 214, 305, 170,
#         65, 256, 257, 259, 115, 136, 207, 105, 132,  96, 169, 210,  64,
#        217, 163, 193, 150,  57, 244, 188, 168, 324, 133, 241, 117, 156,
#        129, 157, 235, 141, 184, 181, 172, 562, 243, 159, 334, 253,  89,
#        134, 311, 204,  68, 228, 126, 275, 142, 263, 304, 469, 273, 145,
#        230, 264, 114, 530, 107, 102, 173, 144, 183, 189, 347, 353, 176,
#        121, 261, 520, 226, 143, 319,  81, 103, 119, 118, 536, 201, 213,
#        220, 563, 229, 238, 331, 164, 398, 402, 266, 215, 254, 306, 216,
#        342, 166, 153, 197, 112, 267, 149, 196, 233, 447, 242, 122, 120,
#        351, 212, 551, 113, 152, 187, 559, 528, 138, 535, 495, 280, 140,
#        182, 218, 171, 332, 227, 313, 185, 440, 360, 314, 123, 147, 418,
#        519, 556, 205, 177, 455, 399, 323, 178, 362, 200, 282,  94, 255,
#        155, 339, 270, 281, 194, 523, 451, 180, 250, 252, 148], dtype=int64)
# 297
# '------ utm_medium ------'
# array(['cpc', '(none)', 'blogger_channel', 'referral', 'banner', 'cpm',
#        'email', 'organic', 'cpv', 'smm', 'push', 'stories', 'smartbanner',
#        'cpa', 'clicks', 'outlook', 'tg', 'blogger_header', 'post', 'app',
#        'landing', 'blogger_stories', '(not set)', 'sms', 'link', 'CPM',
#        'info_text', 'static', 'partner', 'google_cpc', 'vk_smm',
#        'qrcodevideo', 'medium', 'article', 'ok_smm', 'catalogue',
#        'yandex_cpc'], dtype=object)
# 37
# '------ device_category ------'
# array(['mobile', 'desktop', 'tablet'], dtype=object)
# 3
# '------ device_screen_resolution ------'
# array(['320x640', '414x896', '393x873', ..., '360x878', '375x669',
#        '2101x880'], dtype=object)
# 1114
# '------ device_browser ------'
# array(['YaBrowser', 'Android Webview', 'Edge', 'Safari', 'Chrome',
#        'Opera', 'Samsung Internet', 'Firefox', 'Safari (in-app)',
#        'Mozilla Compatible Agent', 'MRCHROME', 'UC Browser', 'MT6735_TD',
#        'Android Runtime', 'Internet Explorer', 'Puffin', '[FBAN',
#        'Coc Coc', 'Instagram 209.0.0.21.119 Android',
#        'Instagram 208.0.0.32.135 Android', 'SeaMonkey', 'Maxthon',
#        'com.vk.vkclient'], dtype=object)
# 23
# '------ geo_country ------'
# array(['Russia', 'Kazakhstan', 'Ukraine', 'Armenia', 'Belarus',
#        'United Kingdom', 'Israel', 'Netherlands', 'Kyrgyzstan', 'Greece',
#        '(not set)', 'Germany', 'United States', 'Andorra', 'Georgia',
#        'Spain', 'Turkey', 'France', 'Latvia', 'United Arab Emirates',
#        'Austria', 'Dominican Republic', 'Cyprus', 'Egypt', 'Canada',
#        'Uzbekistan', 'South Africa', 'Argentina', 'Montenegro', 'Poland',
#        'Ireland', 'Sweden', 'Moldova', 'Qatar', 'Uganda', 'Italy',
#        'Serbia', 'Cambodia', 'Iran', 'Morocco', 'Hungary', 'Croatia',
#        'Maldives', 'Czechia', 'Bulgaria', 'Tajikistan', 'Finland',
#        'Lithuania', 'Bangladesh', 'Switzerland', 'Kenya', 'Seychelles',
#        'Saudi Arabia', 'Palestine', 'India', 'Mexico', 'Mauritius',
#        'Australia', 'Albania', 'Indonesia', 'Estonia', 'North Macedonia',
#        'Nigeria', 'Libya', 'South Korea', 'Malaysia', 'Azerbaijan',
#        'Thailand', 'Singapore', 'Afghanistan', 'Guatemala', 'Lebanon',
#        'Taiwan', 'Brazil', 'Norway', 'Malta', 'Romania', 'Japan', 'Togo',
#        'Belgium', 'Cuba', 'Iceland', 'Denmark', 'Venezuela', 'Tunisia',
#        'China', 'Algeria', 'Vietnam', 'Sri Lanka', 'Tanzania', 'Ecuador',
#        'Oman', 'Bahrain', 'Iraq', 'Faroe Islands', 'Pakistan',
#        'Turkmenistan', 'Syria', 'Svalbard & Jan Mayen', 'Slovenia',
#        'Gibraltar', 'Slovakia', 'Equatorial Guinea', 'Colombia',
#        'Hong Kong', 'Portugal', 'Peru', 'Philippines', 'Côte d’Ivoire',
#        'Myanmar (Burma)', 'Mozambique', 'Nicaragua', 'New Zealand'],
#       dtype=object)
# 113
# '------ geo_city ------'
# array(['Grozny', 'Moscow', 'Saint Petersburg', ..., 'Jurmala',
#        "Land O' Lakes", 'Concord'], dtype=object)
# 1016
# '------ hit_number ------'
# array([  4,  56,  21,  16,   8,  39,   3,  36,  26,   2,  11,   6,   9,
#         42,  14,  48,  22,  64,  43,  20,  27,  29,  62,  31,  17,  24,
#         75,  15,  78, 202,  10,  53,   7,  32,  12,  34,  18,  54,   5,
#         37,  19,  23,  13,  38,  76,  25,  33,  41,  44,  57,  67, 101,
#         28,  61,  86,  59,  35,  52, 497,   1,  58,  55,  91,  49,  90,
#         30,  40,  50, 123, 137,  66,  83,  73, 116,  45,  88,  87,  79,
#         60, 239,  68,  47,  92,  51,  95,  89, 127,  72,  97, 128,  65,
#        184,  69,  63, 181, 102,  71,  77, 221,  46,  96,  74, 105,  81,
#        215,  70, 416, 160, 124,  98, 109, 139, 254, 144, 155, 138, 119,
#         94, 131, 172, 158,  85, 125, 108, 104, 112, 117,  80, 106, 121,
#        140, 235, 111,  82, 216, 354, 100, 291,  99, 110, 122, 113, 294,
#        223, 201, 133, 130, 199, 319, 143, 378, 154,  84, 115,  93, 273,
#        253, 114, 350, 146, 103, 136, 145, 214, 261, 171, 179, 195, 148,
#        107, 161, 228, 233, 180, 186, 419, 149, 162, 371, 279, 129, 185,
#        147, 217, 478, 225, 200, 152, 260, 126, 177, 153, 224, 150, 134,
#        142, 120, 178, 209, 182, 488, 435, 206, 157, 232, 118, 165, 245,
#        183, 238, 192, 450, 176, 205, 135, 169, 174, 277, 151, 269, 189,
#        132, 485, 418, 322, 284, 356, 159, 163, 190, 494, 248, 219, 338,
#        164, 376, 340, 173, 170, 267, 384, 381, 305, 234, 141, 255, 247,
#        194, 398, 258, 272, 382, 465, 303, 243, 203, 168, 204, 166, 175,
#        293, 156, 307, 310, 336, 306, 237, 265, 276, 193, 246, 493, 263,
#        275, 251, 208, 302, 290, 452, 372, 285, 425, 198, 413, 242, 334,
#        472, 308, 231, 299, 188, 241, 295, 227, 244, 296, 365, 324, 498,
#        415, 229, 167, 424, 393, 187, 249, 287, 278, 389, 351, 264, 333,
#        456, 469, 211, 218, 197, 266, 220, 451, 271, 364, 288, 191, 262,
#        222, 207, 360, 414, 210, 446, 315, 420, 327, 409, 281, 391, 367,
#        274, 396, 311, 375, 226, 468, 353, 286, 230, 257, 250, 196, 437,
#        342, 400, 352, 343, 404, 399, 213, 270, 304, 240, 236, 346, 481,
#        344, 430, 433, 440, 259, 395, 282, 326, 212, 318, 380, 314, 379,
#        309, 312, 345, 362, 361, 337, 330, 323, 268, 329, 406, 256, 320,
#        397, 443, 252, 368, 321, 441, 408, 363, 484, 313, 289, 467, 377,
#        349, 297, 301, 292, 438, 359, 421, 347, 487, 385], dtype=int64)
# 413
# '------ hit_page_path ------'
# array(['sberauto.com/cars/6afb1543?rental_page=rental_car',
#        'sberauto.com/cars/all/audi/a3/088f5fa8?utm_source_initial=yandex&utm_medium_initial=cpc&utm_campaign_initial=nSReTmyFtbSjlPrTKoaX|fVHJqnfOFSWcsCBViJGr&utm_content_initial=yXzSAJWSuRbYeLFyMVFl|YjagTPsykUtMSrHgFPJc|xAEYTlJDbQNwQTLGxICQ|dwfnIkMEwJhmnyojmAoc|lFpAoUqEvHoyZfCNRuCR|qEQeQoWWnoVEMwsyhUcz|rjbbNGNkjGThUJNtsWZQ|PmdxcXFdmnXhLVKwdKkP|ZIKCVYXYgRrZdwlVkEEf|HbolMJUevblAbkHClEQa|kqZPVvZmXADsCZxIQwbv|vnTlRpYmthtVDImMLSmr|OfdDOXSwHYclonQJpPxh|YhdYMAYSoTzDKQYzVVMr|HbolMJUevblAbkHClEQa&utm_term_initial=&rental_page=rental_car',
#        'sberauto.com/cars?city=1&city=18&rental_page=rental_only&rental_car=rental_only&page=1',
#        ..., 'podpiska.sberauto.com/?yclid=4494157628785609882',
#        'podpiska.sberauto.com/?yclid=3396410506477864700',
#        'sberauto.com/cars/b0969889?utm_source_initial=yandex&utm_medium_initial=cpc&utm_campaign_initial=RoDitORHdzGfGhNCyEMy|sKuhgZXGwZSwSoGyRIEH&utm_content_initial=yXzSAJWSuRbYeLFyMVFl|IaitBhkxXwnKFSuudkXI|xAEYTlJDbQNwQTLGxICQ|GXPkkTjJEqojipQKfReh|lFpAoUqEvHoyZfCNRuCR|GLOQDhTeSLpqnPbPkXAs|rjbbNGNkjGThUJNtsWZQ|eptPpVmCWHHeAczvNSHk|ZIKCVYXYgRrZdwlVkEEf|HbolMJUevblAbkHClEQa|kqZPVvZmXADsCZxIQwbv|vnTlRpYmthtVDImMLSmr|OfdDOXSwHYclonQJpPxh|YhdYMAYSoTzDKQYzVVMr|HbolMJUevblAbkHClEQa&utm_term_initial=&rental_page=rental_car'],
#       dtype=object)
# 26913
# '------ event_category ------'
# array(['card_web', 'search_form', 'sub_page_view', 'auth', 'listing_ads',
#        'sub_button_click', 'sap_search_form', 'jivosite', 'quiz',
#        'sap_search__form', 'cars', 'chat', 'active_invitation', 'offers',
#        'ad_banner', 'profile_menu', 'scrolling_main_page', 'sub_submit',
#        'footer', 'greenday_sub_submit', 'navigation',
#        'greenday_sub_button_click', 'main_banners', 'header',
#        'greenday_gtm.triggergroup', 'phone', 'greenday_listing_ads',
#        'main_services', 'my_idea', 'credit_landing_pos', 'category_tile',
#        'main_advantages', 'add_ad', 'add_ad_options', 'credit_buttons',
#        'add_ad_additional_information', 'add_ad_price'], dtype=object)
# 37
# '------ event_action ------'
# array(['view_new_card', 'photos', 'search_form_search_btn', 'photos_all',
#        'search_form_region', 'showed_number_ads', 'sub_landing',
#        'sub_car_page', 'view_card', 'search_kpp', 'show_phone_input',
#        'go_to_car_card', 'sub_car_claim_click', 'sap_search_form_cost_to',
#        'proactive invitation shown', 'quiz_start', 'search_form_rental',
#        'search_form_mark_select', 'search_form_search_car_type_select',
#        'sap_search_form_cost_from', 'phone_entered', 'quiz_show',
#        'sub_view_cars_click', 'search_form_modification_select',
#        'sub_open_dialog_click', 'code_sms_entered_success',
#        'view_more_click', 'pagination_click', 'start_chat',
#        'sub_header_link_click', 'search_form_year_to',
#        'sber_id_auth_start', 'search_form_year_from', 'listing_ads_sort',
#        'search_drive', 'typing_in_leasing_chat',
#        'showed_active_invitation', 'sub_view_faq_click',
#        'toggle_leasing_cars_show', 'search_form_model_select',
#        'sub_car_claim_submit_click', 'sub_faq', 'sub_offer_click',
#        'search_form_clear', 'search_power_to', 'search_power_from',
#        'show_sms_code_input', 'go_to_offer', 'start_auth', 'analystlabel',
#        'click_on_menu', 'scrolling_to_advantages',
#        'show_form_lets_get_acquainted', 'click_on_get_code',
#        'sub_submit_success', 'search_km_from', 'search_km_to',
#        'search_form_model_multiselec', 'sub_car_request_submit_click',
#        'go_to_terms', 'search_form_cost_to', 'scrolling_to_services',
#        'automatic_return_to_chat', 'user_message', 'go_to_job',
#        'share_btn', 'phone_auth_start', 'name_entered', 'open_offer',
#        'greenday_sub_submit_success', 'sub_footer_link_click',
#        'click_on_logo', 'search_body_type', 'greenday_get_gift',
#        'search_form_mark_multiselect', 'go_to_special_offers',
#        'click_on_confirm_sms_code', 'view_used_card',
#        'click_on_subscription', 'search_steering_wheel',
#        'search_form_cost_from', 'click_skip_form_lets_get_acquainted',
#        'patronymic_entered', 'click_car_buyback',
#        'sub_callback_submit_click', 'search_engine', 'go_to_support',
#        'search_color', 'greenday_sub_callback_submit_click',
#        'phone_auth_success', 'click_on_my_data',
#        'greenday_sub_view_faq_click', 'go_to_privacy_partners',
#        'proactive invitation rejected', 'auto_subscription_click',
#        'tap_on_phone_495', 'surname_entered',
#        'sub_custom_question_submit_click', 'sub_call_number_click',
#        'sub_banner_click', 'show_popup_this_is_your_account',
#        'showed_call_options', 'greenday_go_to_car_card',
#        'greenday_get_discount', 'chat requested', 'sber_id_auth_success',
#        'go_to_privacy_policy', 'code_sms_incorrect_in',
#        'click_auto_subscription', 'chat established',
#        'click_on_start_chatting', 'green_day_road_help_banner_show',
#        'go_to_my_idea', 'back_to_change_phone', 'click_on_my_ads',
#        'tap_on_phone_800', 'click_on_yes_its_me', 'client initiate chat',
#        'click_pos_credit', 'click_on_contact_us', 'calculate',
#        'greenday_sub_view_cars_click', 'send_code_sms_again',
#        'prechat phrase clicked', 'click_on_request_call',
#        'code_sms_limit_error', 'greenday_sub_footer_link_click',
#        'user gave contacts during chat', 'sub_account_page',
#        'click_on_category', 'click_buy_auto', 'go_to_press_center',
#        'new_year_road_help_banner_show', 'greenday_sub_header_link_click',
#        'add_ad_btn', 'sber_id_auth_back_error', 'sub_submit_error',
#        'jivo_vkontakte', 'jivo_viber',
#        'scrolling_to_help_in_finding_banner',
#        'proactive invitation accepted', 'forward_to_city',
#        'click_car_selection', 'setelem_credit_form_button',
#        'callback requested', 'click_no_help_needed',
#        'showed_form_request_call', 'forward_to_options',
#        'sber_id_auth_show_deactivation_popup', 'scrolling_to_sub_banner',
#        'forward_to_photo', 'scrolling_to_sub_quick_categories',
#        'click_on_wallet', 'click_on_phone', 'offline form shown'],
#       dtype=object)
# 155

# %% [markdown]
# ## Даты и время

# %%
import re

HOUR_PATTERN = re.compile('(\d\d):\d\d:\d\d')

def extract_hour(timestr):
    groups = HOUR_PATTERN.findall(timestr)
    if len(groups) > 0:
        hour = int(groups[0])
    else:
        hour = None
    return hour

# %%
from datetime import datetime

DATE_FORMAT = '%Y-%m-%d'

def extract_year(date_str):
    date = datetime.strptime(date_str, DATE_FORMAT)
    return date.year

def extract_month(date_str):
    date = datetime.strptime(date_str, DATE_FORMAT)
    return date.month

def extract_day(date_str):
    date = datetime.strptime(date_str, DATE_FORMAT)
    return date.day

# %%
merged_df['visit_hour'] = merged_df.apply(lambda row: extract_hour(row['visit_time']),axis=1)
merged_df['visit_year'] = merged_df.apply(lambda row: extract_year(row['visit_date']),axis=1)
merged_df['visit_month'] = merged_df.apply(lambda row: extract_month(row['visit_date']),axis=1)
merged_df['visit_day'] = merged_df.apply(lambda row: extract_day(row['visit_date']),axis=1)

# %%
merged_df = merged_df.drop(['visit_date','visit_time'],axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category  \
# 11640074             1              cpc          mobile
# 7944848             16              cpc          mobile
# 2984725              1              cpc          mobile
# 9921157              1           (none)          mobile
# 9789955              1  blogger_channel         desktop
# ...                ...              ...             ...
# 6206192              2              cpc          mobile
# 7272245              1           (none)          mobile
# 5418430              1            email          mobile
# 13101241             2         referral         desktop
# 1449787              3           banner          mobile
#
#          device_screen_resolution   device_browser geo_country  \
# 11640074                  320x640        YaBrowser      Russia
# 7944848                   414x896        YaBrowser      Russia
# 2984725                   393x873  Android Webview      Russia
# 9921157                   393x873  Android Webview      Russia
# 9789955                  1366x768        YaBrowser      Russia
# ...                           ...              ...         ...
# 6206192                   412x915           Chrome      Russia
# 7272245                   414x736           Safari      Russia
# 5418430                   320x568           Safari      Russia
# 13101241                 1440x900           Chrome      Russia
# 1449787                   428x926           Safari      Russia
#
#                   geo_city  hit_number  \
# 11640074            Grozny           4
# 7944848             Moscow          56
# 2984725   Saint Petersburg          21
# 9921157             Moscow          16
# 9789955               Tver           8
# ...                    ...         ...
# 6206192             Moscow           3
# 7272245        Novosibirsk          14
# 5418430        Sterlitamak          21
# 13101241            Moscow          38
# 1449787             Moscow          31
#
#                                               hit_page_path event_category  \
# 11640074  sberauto.com/cars/6afb1543?rental_page=rental_car       card_web
# 7944848   sberauto.com/cars/all/audi/a3/088f5fa8?utm_sou...       card_web
# 2984725   sberauto.com/cars?city=1&city=18&rental_page=r...    search_form
# 9921157   sberauto.com/cars/e994838f?rental_page=rental_car       card_web
# 9789955   sberauto.com/cars?utm_source_initial=youtube&u...    search_form
# ...                                                     ...            ...
# 6206192    podpiska.sberauto.com/?yclid=3396410506477864700  sub_page_view
# 7272245   sberauto.com/cars/all/bmw/2-serii/884c2872?ren...       card_web
# 5418430   sberauto.com/cars/all/volkswagen/taos/8c0f38cd...       card_web
# 13101241  sberauto.com/cars/b0969889?utm_source_initial=...       card_web
# 1449787   sberauto.com/cars/eb5698f6?utm_source_initial=...       card_web
#
#                     event_action  visit_hour  visit_year  visit_month  \
# 11640074           view_new_card          14        2021            9
# 7944848                   photos          17        2021           12
# 2984725   search_form_search_btn          18        2021           10
# 9921157               photos_all           8        2021            8
# 9789955       search_form_region          21        2021            9
# ...                          ...         ...         ...          ...
# 6206192              sub_landing           1        2021            6
# 7272245            view_new_card           0        2021           11
# 5418430            view_new_card          15        2021           10
# 13101241               view_card           9        2021            8
# 1449787               photos_all           9        2021            9
#
#           visit_day
# 11640074         23
# 7944848          29
# 2984725          14
# 9921157          17
# 9789955           5
# ...             ...
# 6206192          19
# 7272245          23
# 5418430          29
# 13101241         21
# 1449787          20
#
# [156834 rows x 17 columns]

# %% [markdown]
# # Гео - создаем единую колонку из 2500 значений вместо 2х колонок из 250 и 2000

# %%
merged_df['place'] = merged_df.apply(lambda row: row['geo_country'].lower() + '_' + row['geo_city'].lower(), axis=1)
merged_df = merged_df.drop(['geo_country','geo_city'],axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category  \
# 11640074             1              cpc          mobile
# 7944848             16              cpc          mobile
# 2984725              1              cpc          mobile
# 9921157              1           (none)          mobile
# 9789955              1  blogger_channel         desktop
# ...                ...              ...             ...
# 6206192              2              cpc          mobile
# 7272245              1           (none)          mobile
# 5418430              1            email          mobile
# 13101241             2         referral         desktop
# 1449787              3           banner          mobile
#
#          device_screen_resolution   device_browser  hit_number  \
# 11640074                  320x640        YaBrowser           4
# 7944848                   414x896        YaBrowser          56
# 2984725                   393x873  Android Webview          21
# 9921157                   393x873  Android Webview          16
# 9789955                  1366x768        YaBrowser           8
# ...                           ...              ...         ...
# 6206192                   412x915           Chrome           3
# 7272245                   414x736           Safari          14
# 5418430                   320x568           Safari          21
# 13101241                 1440x900           Chrome          38
# 1449787                   428x926           Safari          31
#
#                                               hit_page_path event_category  \
# 11640074  sberauto.com/cars/6afb1543?rental_page=rental_car       card_web
# 7944848   sberauto.com/cars/all/audi/a3/088f5fa8?utm_sou...       card_web
# 2984725   sberauto.com/cars?city=1&city=18&rental_page=r...    search_form
# 9921157   sberauto.com/cars/e994838f?rental_page=rental_car       card_web
# 9789955   sberauto.com/cars?utm_source_initial=youtube&u...    search_form
# ...                                                     ...            ...
# 6206192    podpiska.sberauto.com/?yclid=3396410506477864700  sub_page_view
# 7272245   sberauto.com/cars/all/bmw/2-serii/884c2872?ren...       card_web
# 5418430   sberauto.com/cars/all/volkswagen/taos/8c0f38cd...       card_web
# 13101241  sberauto.com/cars/b0969889?utm_source_initial=...       card_web
# 1449787   sberauto.com/cars/eb5698f6?utm_source_initial=...       card_web
#
#                     event_action  visit_hour  visit_year  visit_month  \
# 11640074           view_new_card          14        2021            9
# 7944848                   photos          17        2021           12
# 2984725   search_form_search_btn          18        2021           10
# 9921157               photos_all           8        2021            8
# 9789955       search_form_region          21        2021            9
# ...                          ...         ...         ...          ...
# 6206192              sub_landing           1        2021            6
# 7272245            view_new_card           0        2021           11
# 5418430            view_new_card          15        2021           10
# 13101241               view_card           9        2021            8
# 1449787               photos_all           9        2021            9
#
#           visit_day                    place
# 11640074         23            russia_grozny
# 7944848          29            russia_moscow
# 2984725          14  russia_saint petersburg
# 9921157          17            russia_moscow
# 9789955           5              russia_tver
# ...             ...                      ...
# 6206192          19            russia_moscow
# 7272245          23       russia_novosibirsk
# 5418430          29       russia_sterlitamak
# 13101241         21            russia_moscow
# 1449787          20            russia_moscow
#
# [156834 rows x 16 columns]

# %%
# places.drop_duplicates().to_csv('extra_data/places.csv')

# %%
# unique_places = set(places.unique())

# %%
# import requests

#API_NINJAS_API_KEY = 'api-key'
#
#def get_coords(place):
#    country, city = place.split(',')
#    return requests.get('https://api.api-ninjas.com/v1/geocoding',headers={'X-Api-Key': API_NINJAS_API_KEY}, params={'city': city, 'country': country})
    
# test_coords = get_coords('Russia,Moscow')

# %%
import json

# resp_dict = json.loads(test_coords.text)[0]

# resp_dict

# %%
# places_df = pd.DataFrame(unique_places, columns=['Place'])

# %%
# places_df

# %%
# places_df = places_df.drop(places_df[places_df['Place'].str.contains('not')].index)
# display(places_df)
# places_df.to_csv('extra_data/places.csv')

# %%
# places_df['geo_api_resp'] = places_df.apply(lambda row: get_coords(row['Place']).text,axis=1)
# display(places_df['geo_api_resp'])
# places_df.to_csv('places_to_responces.csv')

# %%
# places_df = pd.read_csv('extra_data/places_to_responces.csv')
#places_df = places_df.drop(columns=['Unnamed: 0'],axis=1)
#places_df

# %%
def extract_coords(row):
    dict_arr = json.loads(row['geo_api_resp'])
    if len(dict_arr) == 0:
        return None
    else:
        coord_dict = dict_arr[0]
        latitude = coord_dict['latitude']
        longitude = coord_dict['longitude']
        return latitude, longitude

def extract_lat(row):
    dict_arr = json.loads(row['geo_api_resp'])
    if len(dict_arr) == 0:
        return None
    else:
        coord_dict = dict_arr[0]
        latitude = coord_dict['latitude']
        return latitude
    
def extract_long(row):
    dict_arr = json.loads(row['geo_api_resp'])
    if len(dict_arr) == 0:
        return None
    else:
        coord_dict = dict_arr[0]
        longitude = coord_dict['longitude']
        return longitude

#places_df['geo_lat'] = places_df.apply(lambda row: extract_lat(row), axis=1)
#places_df['geo_long'] = places_df.apply(lambda row: extract_long(row), axis=1)

# %%
def get_lat_by_place(place):
    return places_df[places_df['Place'] == place]['geo_lat']

def get_long_by_place(place):
    return places_df[places_df['Place'] == place]['geo_long']

# %%
# merged_df['geo_lat'] = merged_df.apply(lambda row: get_lat_by_place(f'{row["geo_country"]},{row["geo_city"]}') , axis=1)
# merged_df['geo_long'] = merged_df.apply(lambda row: get_long_by_place(f'{row["geo_country"]},{row["geo_city"]}') , axis=1)
# merged_df

# %% [markdown]
# # Преобразование разрешения экрана  (Width X Height)

# %%
def extract_width(res_str):
    wharr = res_str.split('x')
    if len(wharr) == 2:
        return wharr[0]
    else:
        return None
    
def extract_height(res_str):
    wharr = res_str.split('x')
    if len(wharr) == 2:
        return wharr[1]
    else:
        return None

# %%
merged_df['screen_width'] = merged_df.apply(lambda row: extract_width(row['device_screen_resolution']), axis=1)
merged_df['screen_height'] = merged_df.apply(lambda row: extract_height(row['device_screen_resolution']), axis=1)
merged_df = merged_df.drop(['device_screen_resolution'],axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number                                      hit_page_path  \
# 11640074           4  sberauto.com/cars/6afb1543?rental_page=rental_car
# 7944848           56  sberauto.com/cars/all/audi/a3/088f5fa8?utm_sou...
# 2984725           21  sberauto.com/cars?city=1&city=18&rental_page=r...
# 9921157           16  sberauto.com/cars/e994838f?rental_page=rental_car
# 9789955            8  sberauto.com/cars?utm_source_initial=youtube&u...
# ...              ...                                                ...
# 6206192            3   podpiska.sberauto.com/?yclid=3396410506477864700
# 7272245           14  sberauto.com/cars/all/bmw/2-serii/884c2872?ren...
# 5418430           21  sberauto.com/cars/all/volkswagen/taos/8c0f38cd...
# 13101241          38  sberauto.com/cars/b0969889?utm_source_initial=...
# 1449787           31  sberauto.com/cars/eb5698f6?utm_source_initial=...
#
#          event_category            event_action  visit_hour  visit_year  \
# 11640074       card_web           view_new_card          14        2021
# 7944848        card_web                  photos          17        2021
# 2984725     search_form  search_form_search_btn          18        2021
# 9921157        card_web              photos_all           8        2021
# 9789955     search_form      search_form_region          21        2021
# ...                 ...                     ...         ...         ...
# 6206192   sub_page_view             sub_landing           1        2021
# 7272245        card_web           view_new_card           0        2021
# 5418430        card_web           view_new_card          15        2021
# 13101241       card_web               view_card           9        2021
# 1449787        card_web              photos_all           9        2021
#
#           visit_month  visit_day                    place screen_width  \
# 11640074            9         23            russia_grozny          320
# 7944848            12         29            russia_moscow          414
# 2984725            10         14  russia_saint petersburg          393
# 9921157             8         17            russia_moscow          393
# 9789955             9          5              russia_tver         1366
# ...               ...        ...                      ...          ...
# 6206192             6         19            russia_moscow          412
# 7272245            11         23       russia_novosibirsk          414
# 5418430            10         29       russia_sterlitamak          320
# 13101241            8         21            russia_moscow         1440
# 1449787             9         20            russia_moscow          428
#
#          screen_height
# 11640074           640
# 7944848            896
# 2984725            873
# 9921157            873
# 9789955            768
# ...                ...
# 6206192            915
# 7272245            736
# 5418430            568
# 13101241           900
# 1449787            926
#
# [156834 rows x 17 columns]

# %% [markdown]
# # Преобразование и очистка урлов

# %%
from urllib.parse import urlparse


def shorter_path(url_path):
    full_path = urlparse(url_path).path
    path_parts = full_path.split('/')
    path_parts = path_parts[0:1]
    processed_path = '/'.join(path_parts)
    return processed_path

merged_df['hit_page_short_path'] = merged_df.apply(lambda row: shorter_path(row['hit_page_path']),axis=1)
merged_df = merged_df.drop(['hit_page_path'],axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number event_category            event_action  visit_hour  \
# 11640074           4       card_web           view_new_card          14
# 7944848           56       card_web                  photos          17
# 2984725           21    search_form  search_form_search_btn          18
# 9921157           16       card_web              photos_all           8
# 9789955            8    search_form      search_form_region          21
# ...              ...            ...                     ...         ...
# 6206192            3  sub_page_view             sub_landing           1
# 7272245           14       card_web           view_new_card           0
# 5418430           21       card_web           view_new_card          15
# 13101241          38       card_web               view_card           9
# 1449787           31       card_web              photos_all           9
#
#           visit_year  visit_month  visit_day                    place  \
# 11640074        2021            9         23            russia_grozny
# 7944848         2021           12         29            russia_moscow
# 2984725         2021           10         14  russia_saint petersburg
# 9921157         2021            8         17            russia_moscow
# 9789955         2021            9          5              russia_tver
# ...              ...          ...        ...                      ...
# 6206192         2021            6         19            russia_moscow
# 7272245         2021           11         23       russia_novosibirsk
# 5418430         2021           10         29       russia_sterlitamak
# 13101241        2021            8         21            russia_moscow
# 1449787         2021            9         20            russia_moscow
#
#          screen_width screen_height    hit_page_short_path
# 11640074          320           640           sberauto.com
# 7944848           414           896           sberauto.com
# 2984725           393           873           sberauto.com
# 9921157           393           873           sberauto.com
# 9789955          1366           768           sberauto.com
# ...               ...           ...                    ...
# 6206192           412           915  podpiska.sberauto.com
# 7272245           414           736           sberauto.com
# 5418430           320           568           sberauto.com
# 13101241         1440           900           sberauto.com
# 1449787           428           926           sberauto.com
#
# [156834 rows x 17 columns]

# %% [markdown]
# # Преобразование event_ в колонку со свойством целевого действия

# %%
TARGET_EVENTS =  ['sub_car_claim_click', 'sub_car_claim_submit_click',
'sub_open_dialog_click', 'sub_custom_question_submit_click',
'sub_call_number_click', 'sub_callback_submit_click', 'sub_submit_success',
'sub_car_request_submit_click']

TARGET_EVENTS
# Out:
# ['sub_car_claim_click',
#  'sub_car_claim_submit_click',
#  'sub_open_dialog_click',
#  'sub_custom_question_submit_click',
#  'sub_call_number_click',
#  'sub_callback_submit_click',
#  'sub_submit_success',
#  'sub_car_request_submit_click']

# %%
merged_df['event_action'].unique()
# Out:
# array(['view_new_card', 'photos', 'search_form_search_btn', 'photos_all',
#        'search_form_region', 'showed_number_ads', 'sub_landing',
#        'sub_car_page', 'view_card', 'search_kpp', 'show_phone_input',
#        'go_to_car_card', 'sub_car_claim_click', 'sap_search_form_cost_to',
#        'proactive invitation shown', 'quiz_start', 'search_form_rental',
#        'search_form_mark_select', 'search_form_search_car_type_select',
#        'sap_search_form_cost_from', 'phone_entered', 'quiz_show',
#        'sub_view_cars_click', 'search_form_modification_select',
#        'sub_open_dialog_click', 'code_sms_entered_success',
#        'view_more_click', 'pagination_click', 'start_chat',
#        'sub_header_link_click', 'search_form_year_to',
#        'sber_id_auth_start', 'search_form_year_from', 'listing_ads_sort',
#        'search_drive', 'typing_in_leasing_chat',
#        'showed_active_invitation', 'sub_view_faq_click',
#        'toggle_leasing_cars_show', 'search_form_model_select',
#        'sub_car_claim_submit_click', 'sub_faq', 'sub_offer_click',
#        'search_form_clear', 'search_power_to', 'search_power_from',
#        'show_sms_code_input', 'go_to_offer', 'start_auth', 'analystlabel',
#        'click_on_menu', 'scrolling_to_advantages',
#        'show_form_lets_get_acquainted', 'click_on_get_code',
#        'sub_submit_success', 'search_km_from', 'search_km_to',
#        'search_form_model_multiselec', 'sub_car_request_submit_click',
#        'go_to_terms', 'search_form_cost_to', 'scrolling_to_services',
#        'automatic_return_to_chat', 'user_message', 'go_to_job',
#        'share_btn', 'phone_auth_start', 'name_entered', 'open_offer',
#        'greenday_sub_submit_success', 'sub_footer_link_click',
#        'click_on_logo', 'search_body_type', 'greenday_get_gift',
#        'search_form_mark_multiselect', 'go_to_special_offers',
#        'click_on_confirm_sms_code', 'view_used_card',
#        'click_on_subscription', 'search_steering_wheel',
#        'search_form_cost_from', 'click_skip_form_lets_get_acquainted',
#        'patronymic_entered', 'click_car_buyback',
#        'sub_callback_submit_click', 'search_engine', 'go_to_support',
#        'search_color', 'greenday_sub_callback_submit_click',
#        'phone_auth_success', 'click_on_my_data',
#        'greenday_sub_view_faq_click', 'go_to_privacy_partners',
#        'proactive invitation rejected', 'auto_subscription_click',
#        'tap_on_phone_495', 'surname_entered',
#        'sub_custom_question_submit_click', 'sub_call_number_click',
#        'sub_banner_click', 'show_popup_this_is_your_account',
#        'showed_call_options', 'greenday_go_to_car_card',
#        'greenday_get_discount', 'chat requested', 'sber_id_auth_success',
#        'go_to_privacy_policy', 'code_sms_incorrect_in',
#        'click_auto_subscription', 'chat established',
#        'click_on_start_chatting', 'green_day_road_help_banner_show',
#        'go_to_my_idea', 'back_to_change_phone', 'click_on_my_ads',
#        'tap_on_phone_800', 'click_on_yes_its_me', 'client initiate chat',
#        'click_pos_credit', 'click_on_contact_us', 'calculate',
#        'greenday_sub_view_cars_click', 'send_code_sms_again',
#        'prechat phrase clicked', 'click_on_request_call',
#        'code_sms_limit_error', 'greenday_sub_footer_link_click',
#        'user gave contacts during chat', 'sub_account_page',
#        'click_on_category', 'click_buy_auto', 'go_to_press_center',
#        'new_year_road_help_banner_show', 'greenday_sub_header_link_click',
#        'add_ad_btn', 'sber_id_auth_back_error', 'sub_submit_error',
#        'jivo_vkontakte', 'jivo_viber',
#        'scrolling_to_help_in_finding_banner',
#        'proactive invitation accepted', 'forward_to_city',
#        'click_car_selection', 'setelem_credit_form_button',
#        'callback requested', 'click_no_help_needed',
#        'showed_form_request_call', 'forward_to_options',
#        'sber_id_auth_show_deactivation_popup', 'scrolling_to_sub_banner',
#        'forward_to_photo', 'scrolling_to_sub_quick_categories',
#        'click_on_wallet', 'click_on_phone', 'offline form shown'],
#       dtype=object)

# %%
merged_df['event_target'] = merged_df.apply(lambda row: row['event_action'] in TARGET_EVENTS,axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number event_category            event_action  visit_hour  \
# 11640074           4       card_web           view_new_card          14
# 7944848           56       card_web                  photos          17
# 2984725           21    search_form  search_form_search_btn          18
# 9921157           16       card_web              photos_all           8
# 9789955            8    search_form      search_form_region          21
# ...              ...            ...                     ...         ...
# 6206192            3  sub_page_view             sub_landing           1
# 7272245           14       card_web           view_new_card           0
# 5418430           21       card_web           view_new_card          15
# 13101241          38       card_web               view_card           9
# 1449787           31       card_web              photos_all           9
#
#           visit_year  visit_month  visit_day                    place  \
# 11640074        2021            9         23            russia_grozny
# 7944848         2021           12         29            russia_moscow
# 2984725         2021           10         14  russia_saint petersburg
# 9921157         2021            8         17            russia_moscow
# 9789955         2021            9          5              russia_tver
# ...              ...          ...        ...                      ...
# 6206192         2021            6         19            russia_moscow
# 7272245         2021           11         23       russia_novosibirsk
# 5418430         2021           10         29       russia_sterlitamak
# 13101241        2021            8         21            russia_moscow
# 1449787         2021            9         20            russia_moscow
#
#          screen_width screen_height    hit_page_short_path  event_target
# 11640074          320           640           sberauto.com         False
# 7944848           414           896           sberauto.com         False
# 2984725           393           873           sberauto.com         False
# 9921157           393           873           sberauto.com         False
# 9789955          1366           768           sberauto.com         False
# ...               ...           ...                    ...           ...
# 6206192           412           915  podpiska.sberauto.com         False
# 7272245           414           736           sberauto.com         False
# 5418430           320           568           sberauto.com         False
# 13101241         1440           900           sberauto.com         False
# 1449787           428           926           sberauto.com         False
#
# [156834 rows x 18 columns]

# %%
merged_df = merged_df.drop(['event_category', 'event_action'],axis=1)
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number  visit_hour  visit_year  visit_month  visit_day  \
# 11640074           4          14        2021            9         23
# 7944848           56          17        2021           12         29
# 2984725           21          18        2021           10         14
# 9921157           16           8        2021            8         17
# 9789955            8          21        2021            9          5
# ...              ...         ...         ...          ...        ...
# 6206192            3           1        2021            6         19
# 7272245           14           0        2021           11         23
# 5418430           21          15        2021           10         29
# 13101241          38           9        2021            8         21
# 1449787           31           9        2021            9         20
#
#                             place screen_width screen_height  \
# 11640074            russia_grozny          320           640
# 7944848             russia_moscow          414           896
# 2984725   russia_saint petersburg          393           873
# 9921157             russia_moscow          393           873
# 9789955               russia_tver         1366           768
# ...                           ...          ...           ...
# 6206192             russia_moscow          412           915
# 7272245        russia_novosibirsk          414           736
# 5418430        russia_sterlitamak          320           568
# 13101241            russia_moscow         1440           900
# 1449787             russia_moscow          428           926
#
#             hit_page_short_path  event_target
# 11640074           sberauto.com         False
# 7944848            sberauto.com         False
# 2984725            sberauto.com         False
# 9921157            sberauto.com         False
# 9789955            sberauto.com         False
# ...                         ...           ...
# 6206192   podpiska.sberauto.com         False
# 7272245            sberauto.com         False
# 5418430            sberauto.com         False
# 13101241           sberauto.com         False
# 1449787            sberauto.com         False
#
# [156834 rows x 16 columns]

# %% [markdown]
# # Преобразование данных в категориальный тип

# %%
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number  visit_hour  visit_year  visit_month  visit_day  \
# 11640074           4          14        2021            9         23
# 7944848           56          17        2021           12         29
# 2984725           21          18        2021           10         14
# 9921157           16           8        2021            8         17
# 9789955            8          21        2021            9          5
# ...              ...         ...         ...          ...        ...
# 6206192            3           1        2021            6         19
# 7272245           14           0        2021           11         23
# 5418430           21          15        2021           10         29
# 13101241          38           9        2021            8         21
# 1449787           31           9        2021            9         20
#
#                             place screen_width screen_height  \
# 11640074            russia_grozny          320           640
# 7944848             russia_moscow          414           896
# 2984725   russia_saint petersburg          393           873
# 9921157             russia_moscow          393           873
# 9789955               russia_tver         1366           768
# ...                           ...          ...           ...
# 6206192             russia_moscow          412           915
# 7272245        russia_novosibirsk          414           736
# 5418430        russia_sterlitamak          320           568
# 13101241            russia_moscow         1440           900
# 1449787             russia_moscow          428           926
#
#             hit_page_short_path  event_target
# 11640074           sberauto.com         False
# 7944848            sberauto.com         False
# 2984725            sberauto.com         False
# 9921157            sberauto.com         False
# 9789955            sberauto.com         False
# ...                         ...           ...
# 6206192   podpiska.sberauto.com         False
# 7272245            sberauto.com         False
# 5418430            sberauto.com         False
# 13101241           sberauto.com         False
# 1449787            sberauto.com         False
#
# [156834 rows x 16 columns]

# %%
merged_df['hit_page_short_path'].unique()
# Out:
# array(['sberauto.com', 'podpiska.sberauto.com', '',
#        'client.sap.sberauto-team.com', 'client.stage.sberauto.com',
#        'client.saptest.sberauto-team.com', 'client.preprod.sberauto.com',
#        'localhost', 'client.degipti.sberauto-team.com',
#        'client.vkarpin.sberauto-team.com',
#        'sberauto-client.sap.sberauto.com', 'client.stage2.sberauto.com',
#        'client.ap.sberauto-team.com',
#        'client.egolyagina.sberauto-team.com',
#        'podpiska-sberauto-com.translate.goog',
#        'client.opetrov.sberauto-team.com',
#        'sberauto-client.vsitnikova.sberauto.com',
#        'client-podpiska.sap.sberauto-team.com',
#        'client.aromanchuk.sberauto-team.com',
#        'client.np.sberauto-team.com',
#        'client.knikolaev.sberauto-team.com',
#        'client.agrebenschikov.sberauto-team.com',
#        'client.jscherbinin.sberauto-team.com',
#        'client.aahmedova.sberauto-team.com', 'saptest.sberauto-team.com',
#        'stage2.sberauto.com', 'client-podpiska.saptest.sberauto-team.com'],
#       dtype=object)

# %%
column_names = merged_df.columns.tolist()
for column in column_names:
    display(f'------ {column} ------')
    display(merged_df[column].unique())
    display(merged_df[column].nunique())
# Out:
# '------ session_id ------'
# array(['6914769160598479845.1632396262.1632396262',
#        '496453351534802252.1640788638.1640788638',
#        '234484647397443835.1634224382.1634224382', ...,
#        '3624796273103333147.1635510044.1635510044',
#        '7683576630226201306.1629525600.1629525600',
#        '1527645312481816566.1632121142.1632121142'], dtype=object)
# 137668
# '------ client_id ------'
# array([1609970154.1632397, 115589553.16405436, '54595211.1634224379', ...,
#        843963649.1635511, 1788972092.1629498, 355682641.1631908],
#       dtype=object)
# 127644
# '------ visit_number ------'
# array([  1,  16,   2,   4,   9,  10,   3,   5,  11,  66,  54,   7,  23,
#          6,   8,  60, 110,  15,  17,  18,  51,  63,  30,  27,  13,  19,
#         29,  49,  61,  36,  46, 146,  38,  21, 309,  14,  12,  87,  95,
#         83,  20, 111, 139,  34,  70, 505,  48,  42,  74, 158,  31, 127,
#         22,  26,  33, 284, 308,  55, 131, 507, 283,  25,  78,  24,  72,
#         39, 125, 262,  75,  52,  62,  76, 104,  28,  35,  58,  79,  41,
#        135, 277,  73, 100,  92, 108,  97, 116, 246,  71,  85,  88,  67,
#        160, 222,  80, 268,  44, 376,  84, 245,  37,  86,  45, 236,  47,
#         59, 199, 161, 240,  91, 128,  93, 174, 130,  56,  32,  43,  40,
#        223,  98, 167, 151, 186,  69,  53, 124,  77, 302, 474,  90, 137,
#        109, 106,  82, 154, 101, 202,  99, 162,  50, 192, 214, 305, 170,
#         65, 256, 257, 259, 115, 136, 207, 105, 132,  96, 169, 210,  64,
#        217, 163, 193, 150,  57, 244, 188, 168, 324, 133, 241, 117, 156,
#        129, 157, 235, 141, 184, 181, 172, 562, 243, 159, 334, 253,  89,
#        134, 311, 204,  68, 228, 126, 275, 142, 263, 304, 469, 273, 145,
#        230, 264, 114, 530, 107, 102, 173, 144, 183, 189, 347, 353, 176,
#        121, 261, 520, 226, 143, 319,  81, 103, 119, 118, 536, 201, 213,
#        220, 563, 229, 238, 331, 164, 398, 402, 266, 215, 254, 306, 216,
#        342, 166, 153, 197, 112, 267, 149, 196, 233, 447, 242, 122, 120,
#        351, 212, 551, 113, 152, 187, 559, 528, 138, 535, 495, 280, 140,
#        182, 218, 171, 332, 227, 313, 185, 440, 360, 314, 123, 147, 418,
#        519, 556, 205, 177, 455, 399, 323, 178, 362, 200, 282,  94, 255,
#        155, 339, 270, 281, 194, 523, 451, 180, 250, 252, 148], dtype=int64)
# 297
# '------ utm_medium ------'
# array(['cpc', '(none)', 'blogger_channel', 'referral', 'banner', 'cpm',
#        'email', 'organic', 'cpv', 'smm', 'push', 'stories', 'smartbanner',
#        'cpa', 'clicks', 'outlook', 'tg', 'blogger_header', 'post', 'app',
#        'landing', 'blogger_stories', '(not set)', 'sms', 'link', 'CPM',
#        'info_text', 'static', 'partner', 'google_cpc', 'vk_smm',
#        'qrcodevideo', 'medium', 'article', 'ok_smm', 'catalogue',
#        'yandex_cpc'], dtype=object)
# 37
# '------ device_category ------'
# array(['mobile', 'desktop', 'tablet'], dtype=object)
# 3
# '------ device_browser ------'
# array(['YaBrowser', 'Android Webview', 'Edge', 'Safari', 'Chrome',
#        'Opera', 'Samsung Internet', 'Firefox', 'Safari (in-app)',
#        'Mozilla Compatible Agent', 'MRCHROME', 'UC Browser', 'MT6735_TD',
#        'Android Runtime', 'Internet Explorer', 'Puffin', '[FBAN',
#        'Coc Coc', 'Instagram 209.0.0.21.119 Android',
#        'Instagram 208.0.0.32.135 Android', 'SeaMonkey', 'Maxthon',
#        'com.vk.vkclient'], dtype=object)
# 23
# '------ hit_number ------'
# array([  4,  56,  21,  16,   8,  39,   3,  36,  26,   2,  11,   6,   9,
#         42,  14,  48,  22,  64,  43,  20,  27,  29,  62,  31,  17,  24,
#         75,  15,  78, 202,  10,  53,   7,  32,  12,  34,  18,  54,   5,
#         37,  19,  23,  13,  38,  76,  25,  33,  41,  44,  57,  67, 101,
#         28,  61,  86,  59,  35,  52, 497,   1,  58,  55,  91,  49,  90,
#         30,  40,  50, 123, 137,  66,  83,  73, 116,  45,  88,  87,  79,
#         60, 239,  68,  47,  92,  51,  95,  89, 127,  72,  97, 128,  65,
#        184,  69,  63, 181, 102,  71,  77, 221,  46,  96,  74, 105,  81,
#        215,  70, 416, 160, 124,  98, 109, 139, 254, 144, 155, 138, 119,
#         94, 131, 172, 158,  85, 125, 108, 104, 112, 117,  80, 106, 121,
#        140, 235, 111,  82, 216, 354, 100, 291,  99, 110, 122, 113, 294,
#        223, 201, 133, 130, 199, 319, 143, 378, 154,  84, 115,  93, 273,
#        253, 114, 350, 146, 103, 136, 145, 214, 261, 171, 179, 195, 148,
#        107, 161, 228, 233, 180, 186, 419, 149, 162, 371, 279, 129, 185,
#        147, 217, 478, 225, 200, 152, 260, 126, 177, 153, 224, 150, 134,
#        142, 120, 178, 209, 182, 488, 435, 206, 157, 232, 118, 165, 245,
#        183, 238, 192, 450, 176, 205, 135, 169, 174, 277, 151, 269, 189,
#        132, 485, 418, 322, 284, 356, 159, 163, 190, 494, 248, 219, 338,
#        164, 376, 340, 173, 170, 267, 384, 381, 305, 234, 141, 255, 247,
#        194, 398, 258, 272, 382, 465, 303, 243, 203, 168, 204, 166, 175,
#        293, 156, 307, 310, 336, 306, 237, 265, 276, 193, 246, 493, 263,
#        275, 251, 208, 302, 290, 452, 372, 285, 425, 198, 413, 242, 334,
#        472, 308, 231, 299, 188, 241, 295, 227, 244, 296, 365, 324, 498,
#        415, 229, 167, 424, 393, 187, 249, 287, 278, 389, 351, 264, 333,
#        456, 469, 211, 218, 197, 266, 220, 451, 271, 364, 288, 191, 262,
#        222, 207, 360, 414, 210, 446, 315, 420, 327, 409, 281, 391, 367,
#        274, 396, 311, 375, 226, 468, 353, 286, 230, 257, 250, 196, 437,
#        342, 400, 352, 343, 404, 399, 213, 270, 304, 240, 236, 346, 481,
#        344, 430, 433, 440, 259, 395, 282, 326, 212, 318, 380, 314, 379,
#        309, 312, 345, 362, 361, 337, 330, 323, 268, 329, 406, 256, 320,
#        397, 443, 252, 368, 321, 441, 408, 363, 484, 313, 289, 467, 377,
#        349, 297, 301, 292, 438, 359, 421, 347, 487, 385], dtype=int64)
# 413
# '------ visit_hour ------'
# array([14, 17, 18,  8, 21, 10, 19, 22, 13, 16, 15,  7,  5,  9, 23, 11, 12,
#         3,  0,  1,  6, 20,  2,  4], dtype=int64)
# 24
# '------ visit_year ------'
# array([2021], dtype=int64)
# 1
# '------ visit_month ------'
# array([ 9, 12, 10,  8, 11,  5,  6,  7], dtype=int64)
# 8
# '------ visit_day ------'
# array([23, 29, 14, 17,  5, 26, 21,  7, 28, 16, 20, 13,  3, 24,  2, 30, 10,
#        27, 19,  6, 18, 11, 22,  1, 15, 25,  8, 31, 12,  9,  4],
#       dtype=int64)
# 31
# '------ place ------'
# array(['russia_grozny', 'russia_moscow', 'russia_saint petersburg', ...,
#        'latvia_jurmala', "united states_land o' lakes",
#        'united states_concord'], dtype=object)
# 1096
# '------ screen_width ------'
# array(['320', '414', '393', '1366', '1920', '375', '412', '360', '1280',
#        '390', '2048', '768', '424', '1600', '385', '1536', '428', '384',
#        '486', '3440', '834', '361', '363', '1440', '2560', '1792', '2304',
#        '2240', '534', '1680', '1824', '1024', '601', '851', '1368', '600',
#        '1200', '1093', '377', '2195', '353', '376', '640', '800', '1739',
#        '2752', '720', '1360', '512', '810', '339', '418', '712', '694',
#        '562', '1138', '590', '732', '400', '1603', '820', '451', '1740',
#        '396', '760', '1164', '780', '1152', '1450', '976', '740', '3206',
#        '1120', '892', '343', '1512', '1835', '854', '686', '432', '869',
#        '509', '1344', '846', '1707', '1955', '2000', '346', '421', '960',
#        '789', '463', '753', '1567', '1400', '1862', '1302', '1098',
#        '2275', '380', '1114', '524', '1728', '1829', '501', '3840', '458',
#        '1364', '3072', '491', '1231', '344', '450', '1715', '1255',
#        '1865', '2011', '401', '1842', '1967', '1423', '485', '411', '962',
#        '1750', '455', '374', '2416', '1238', '452', '873', '462', '1500',
#        '1080', '3008', '2328', '427', '1355', '1564', '441', '2950',
#        '674', '786', '1327', '744', '771', '1067', '1900', '1720', '1463',
#        '1412', '2049', '356', '915', '1235', '586', '1670', '480', '408',
#        '748', '1000', '515', '1950', '442', '1291', '1639', '689', '1081',
#        '437', '2561', '1901', '3200', '1676', '2116', '610', '1130',
#        '2880', '388', '1336', '856', '842', '747', '1677', '813', '1318',
#        '1746', '1825', '1455', '1334', '1800', '1821', '461', '2294',
#        '350', '1477', '465', '1517', '464', '392', '832', '1504', '985',
#        '1376', '1701', '1088', '1856', '1742', '1778', '1058', '1970',
#        '1078', '770', '822', '661', '391', '338', '517', '825', '2176',
#        '1963', '883', '1620', '1784', '848', '1510', '1525', '1475',
#        '2219', '2354', '818', '1205', '1444', '1160', '1414', '658',
#        '1321', '957', '1202', '683', '423', '902', '918', '445', '1281',
#        '295', '1708', '347', '1474', '833', '1494', '493', '3360', '403',
#        '1625', '1524', '830', '398', '1730', '5120', '1254', '1139',
#        '454', '1050', '1418', '1102', '443', '1179', '321', '2226', '420',
#        '381', '1372', '919', '1443', '479', '1576', '1451', '2319',
#        '2926', '1585', '1117', '1646', '1718', '1918', '569', '1768',
#        '2138', '368', '1175', '483', '1580', '734', '447', '2544', '1595',
#        '1228', '1417', '911', '394', '1260', '1147', '4096', '1298',
#        '1168', '602', '942', '2160', '1863', '878', '362', '372', '2196',
#        '1760', '1068', '1242', '858', '1790', '845', '348', '351', '540',
#        '1089', '1480', '1506', '900', '1657', '1433', '413', '582', '431',
#        '749', '879', '1106', '2458', '378', '1648', '1442', '1143',
#        '2296', '907', '1085', '1492', '588', '430', '1949', '556', '1650',
#        '1343', '2118', '772', '444', '467', '535', '397', '1696', '2793',
#        '620', '2445', '288', '5760', '699', '474', '1421', '1397', '3414',
#        '0', '817', '607', '471', '1257', '1537', '1587', '797', '1229',
#        '518', '837', '525', '1424', '676', '1476', '1656', '1387', '840',
#        '1561', '478', '466', '2192', '1692', '628', '1402', '1004', '550',
#        '1883', '1685', '850', '2400', '750', '738', '448', '573', '1290',
#        '1840', '3478', '931', '1807', '1498', '470', '2235', '1513',
#        '697', '1329', '1803', '342', '1624', '500', '570', '2188', '2056',
#        '1005', '823', '735', '1346', '1408', '2493', '382', '762', '2657',
#        '2099', '2792', '1095', '1960', '1040', '2101'], dtype=object)
# 433
# '------ screen_height ------'
# array(['640', '896', '873', '768', '1080', '812', '568', '869', '760',
#        '780', '915', '736', '892', '720', '844', '1200', '1152', '846',
#        '1024', '918', '712', '900', '851', '854', '864', '926', '667',
#        '732', '1025', '1440', '1194', '722', '797', '800', '1120', '1296',
#        '786', '771', '1006', '1260', '876', '833', '693', '320', '1050',
#        '740', '1140', '820', '962', '393', '912', '960', '770', '1920',
#        '615', '1600', '1366', '658', '883', '837', '811', '699', '1235',
#        '894', '765', '823', '813', '782', '360', '848', '772', '748',
#        '979', '845', '942', '814', '1280', '817', '1110', '753', '830',
#        '976', '735', '1138', '832', '908', '1216', '1112', '694', '822',
#        '412', '569', '655', '666', '818', '875', '679', '867', '824',
#        '902', '1180', '676', '747', '665', '792', '880', '806', '963',
#        '684', '816', '1040', '418', '1804', '700', '721', '724', '982',
#        '1032', '906', '879', '749', '534', '1098', '755', '744', '1130',
#        '819', '480', '840', '1067', '756', '1100', '2000', '570', '730',
#        '911', '897', '889', '938', '1441', '600', '872', '769', '793',
#        '342', '925', '339', '877', '602', '881', '1205', '858', '1048',
#        '621', '1002', '798', '807', '733', '618', '1279', '887', '696',
#        '907', '778', '1117', '1029', '1086', '750', '895', '1728', '815',
#        '611', '576', '975', '945', '1143', '742', '686', '2655', '803',
#        '978', '1049', '1131', '828', '670', '674', '594', '856', '1026',
#        '1106', '871', '984', '969', '1064', '890', '601', '913', '809',
#        '1019', '910', '716', '836', '790', '891', '932', '424', '1000',
#        '1053', '1692', '794', '1310', '939', '762', '1043', '956', '1659',
#        '1003', '842', '936', '746', '1133', '1091', '804', '659', '680',
#        '795', '863', '2369', '669', '692', '796', '952', '677', '757',
#        '759', '857', '610', '940', '865', '1031', '886', '396', '2160',
#        '1182', '931', '1097', '950', '785', '727', '922', '1087', '1102',
#        '1922', '898', '683', '827', '1249', '958', '1070', '994', '1800',
#        '943', '1191', '623', '706', '1620', '888', '861', '752', '893',
#        '783', '860', '1022', '2560', '375', '825', '1141', '1201', '933',
#        '1334', '986', '831', '668', '870', '853', '1123', '384', '554',
#        '972', '774', '652', '937', '957', '685', '919', '691', '1400',
#        '967', '1005', '808', '1108', '874', '980', '596', '688', '372',
#        '1036', '826', '697', '385', '1318', '914', '711', '1224', '1104',
#        '682', '850', '731', '781', '1007', '766', '959', '923', '451',
#        '1248', '1276', '928', '743', '642', '999', '2437', '773', '916',
#        '961', '1443', '687', '614', '829', '648', '935', '1151', '1890',
#        '810', '1082', '899', '728', '705', '709', '689', '1035', '738',
#        '1252', '821', '802', '468', '539', '719', '955', '739', '1305',
#        '1646', '644', '432', '628', '841', '690', '581', '992', '1203',
#        '661', '664', '729', '1028', '946', '1258', '985', '784', '847',
#        '920', '1018', '1431', '734', '577', '904', '843', '647', '657',
#        '1359', '924', '971', '612', '1078', '654', '563', '3840', '1171',
#        '710', '990', '953', '745', '995', '791', '639', '1010', '627',
#        '371', '835', '1027', '839', '1153', '2880', '849', '1011', '862',
#        '787', '550', '622', '1383', '1450', '1033', '1294', '540', '1076',
#        '764', '965', '1291', '673', '1333', '859', '1037', '1183', '1044',
#        '714', '754', '1030', '929', '901', '954', '620', '1571', '909',
#        '884', '1375', '608', '1137', '763', '1299', '1001', '1089',
#        '1707', '0', '1301', '801', '1317', '363', '2350', '458', '1146',
#        '471', '564', '1004', '378', '285', '695', '983', '1265', '1058',
#        '882', '1114', '678', '1264', '1233', '789', '565', '343', '1129',
#        '1059', '718', '948', '392', '2530', '1350', '1179', '1063', '970',
#        '575', '997', '1957', '536', '973', '524', '1016', '838', '427',
#        '1257', '1015', '606', '993', '1231', '758', '1329', '707', '1312',
#        '834', '964', '515', '903', '998', '878', '1495', '450', '1181',
#        '1570', '1103', '1874'], dtype=object)
# 515
# '------ hit_page_short_path ------'
# array(['sberauto.com', 'podpiska.sberauto.com', '',
#        'client.sap.sberauto-team.com', 'client.stage.sberauto.com',
#        'client.saptest.sberauto-team.com', 'client.preprod.sberauto.com',
#        'localhost', 'client.degipti.sberauto-team.com',
#        'client.vkarpin.sberauto-team.com',
#        'sberauto-client.sap.sberauto.com', 'client.stage2.sberauto.com',
#        'client.ap.sberauto-team.com',
#        'client.egolyagina.sberauto-team.com',
#        'podpiska-sberauto-com.translate.goog',
#        'client.opetrov.sberauto-team.com',
#        'sberauto-client.vsitnikova.sberauto.com',
#        'client-podpiska.sap.sberauto-team.com',
#        'client.aromanchuk.sberauto-team.com',
#        'client.np.sberauto-team.com',
#        'client.knikolaev.sberauto-team.com',
#        'client.agrebenschikov.sberauto-team.com',
#        'client.jscherbinin.sberauto-team.com',
#        'client.aahmedova.sberauto-team.com', 'saptest.sberauto-team.com',
#        'stage2.sberauto.com', 'client-podpiska.saptest.sberauto-team.com'],
#       dtype=object)
# 27
# '------ event_target ------'
# array([False,  True])
# 2

# %%
merged_df['screen_width'] = pd.to_numeric(merged_df['screen_width'], downcast='integer')
merged_df['screen_height'] = pd.to_numeric(merged_df['screen_height'], downcast='integer')
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number  visit_hour  visit_year  visit_month  visit_day  \
# 11640074           4          14        2021            9         23
# 7944848           56          17        2021           12         29
# 2984725           21          18        2021           10         14
# 9921157           16           8        2021            8         17
# 9789955            8          21        2021            9          5
# ...              ...         ...         ...          ...        ...
# 6206192            3           1        2021            6         19
# 7272245           14           0        2021           11         23
# 5418430           21          15        2021           10         29
# 13101241          38           9        2021            8         21
# 1449787           31           9        2021            9         20
#
#                             place  screen_width  screen_height  \
# 11640074            russia_grozny           320            640
# 7944848             russia_moscow           414            896
# 2984725   russia_saint petersburg           393            873
# 9921157             russia_moscow           393            873
# 9789955               russia_tver          1366            768
# ...                           ...           ...            ...
# 6206192             russia_moscow           412            915
# 7272245        russia_novosibirsk           414            736
# 5418430        russia_sterlitamak           320            568
# 13101241            russia_moscow          1440            900
# 1449787             russia_moscow           428            926
#
#             hit_page_short_path  event_target
# 11640074           sberauto.com         False
# 7944848            sberauto.com         False
# 2984725            sberauto.com         False
# 9921157            sberauto.com         False
# 9789955            sberauto.com         False
# ...                         ...           ...
# 6206192   podpiska.sberauto.com         False
# 7272245            sberauto.com         False
# 5418430            sberauto.com         False
# 13101241           sberauto.com         False
# 1449787            sberauto.com         False
#
# [156834 rows x 16 columns]

# %%
CATEGORY_COLUMNS = ['utm_medium','device_category','device_browser','hit_page_short_path','event_target', 'place']

for col in CATEGORY_COLUMNS:
    merged_df[col] = merged_df[col].astype("category")
    
merged_df
# Out:
#                                          session_id            client_id  \
# 11640074  6914769160598479845.1632396262.1632396262     1609970154.16324
# 7944848    496453351534802252.1640788638.1640788638     115589553.164054
# 2984725    234484647397443835.1634224382.1634224382  54595211.1634224379
# 9921157   6004271097826724266.1629178285.1629178285    1397978304.162918
# 9789955   5934916245105479746.1630867524.1630867524    1381830369.163087
# ...                                             ...                  ...
# 6206192   4047877532732397984.1624057079.1624057079     942469931.162402
# 7272245   4607612454038147473.1637618069.1637618069    1072793373.163762
# 5418430   3624796273103333147.1635510044.1635510044     843963649.163551
# 13101241  7683576630226201306.1629525600.1629525600     1788972092.16295
# 1449787   1527645312481816566.1632121142.1632121142     355682641.163191
#
#           visit_number       utm_medium device_category   device_browser  \
# 11640074             1              cpc          mobile        YaBrowser
# 7944848             16              cpc          mobile        YaBrowser
# 2984725              1              cpc          mobile  Android Webview
# 9921157              1           (none)          mobile  Android Webview
# 9789955              1  blogger_channel         desktop        YaBrowser
# ...                ...              ...             ...              ...
# 6206192              2              cpc          mobile           Chrome
# 7272245              1           (none)          mobile           Safari
# 5418430              1            email          mobile           Safari
# 13101241             2         referral         desktop           Chrome
# 1449787              3           banner          mobile           Safari
#
#           hit_number  visit_hour  visit_year  visit_month  visit_day  \
# 11640074           4          14        2021            9         23
# 7944848           56          17        2021           12         29
# 2984725           21          18        2021           10         14
# 9921157           16           8        2021            8         17
# 9789955            8          21        2021            9          5
# ...              ...         ...         ...          ...        ...
# 6206192            3           1        2021            6         19
# 7272245           14           0        2021           11         23
# 5418430           21          15        2021           10         29
# 13101241          38           9        2021            8         21
# 1449787           31           9        2021            9         20
#
#                             place  screen_width  screen_height  \
# 11640074            russia_grozny           320            640
# 7944848             russia_moscow           414            896
# 2984725   russia_saint petersburg           393            873
# 9921157             russia_moscow           393            873
# 9789955               russia_tver          1366            768
# ...                           ...           ...            ...
# 6206192             russia_moscow           412            915
# 7272245        russia_novosibirsk           414            736
# 5418430        russia_sterlitamak           320            568
# 13101241            russia_moscow          1440            900
# 1449787             russia_moscow           428            926
#
#             hit_page_short_path event_target
# 11640074           sberauto.com        False
# 7944848            sberauto.com        False
# 2984725            sberauto.com        False
# 9921157            sberauto.com        False
# 9789955            sberauto.com        False
# ...                         ...          ...
# 6206192   podpiska.sberauto.com        False
# 7272245            sberauto.com        False
# 5418430            sberauto.com        False
# 13101241           sberauto.com        False
# 1449787            sberauto.com        False
#
# [156834 rows x 16 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse=False)

# %%
data_categories = merged_df[CATEGORY_COLUMNS]

ohe.fit(data_categories)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# OneHotEncoder(sparse=False, sparse_output=False)

# %%
ohe_merged = ohe.transform(data_categories)

# %%
ohe.get_feature_names_out()
# Out:
# array(['utm_medium_(none)', 'utm_medium_(not set)', 'utm_medium_CPM', ...,
#        'place_vietnam_da nang', 'place_vietnam_hanoi',
#        'place_vietnam_ho chi minh city'], dtype=object)

# %%
merged_df[ohe.get_feature_names_out()] = ohe_merged
merged_df.drop(CATEGORY_COLUMNS,axis=1)

# %% [markdown]
# # Стандартизация количественных типов

# %%
merged_df.to_csv('data_samples/sample_1.csv')
